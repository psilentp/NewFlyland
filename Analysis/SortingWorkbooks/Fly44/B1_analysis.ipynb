# %%
from pylab import *
from sklearn import decomposition
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import random
import sys
from sklearn.cluster import KMeans

analysis_lib = '/Users/psilentp/Documents/Projects/NewFlyland/Analysis/'
sys.path.append(analysis_lib)

import flyphys as fph
import defaults
import sorters as srtr
import sorter_view as sview

dataroot = '/Users/psilentp/Dropbox/Data/LeftRight/'

# %%
fly = fph.get_fly_in_rootdir(dataroot,44,0,rec_location = 'B1')
fly_cntrlr = fph.FlyController(fly)

# %%
import signal_tools as stools
tmp_signal = stools.get_low_filter(fly.signals['AMsysCh1'],5000)
sweep = tmp_signal
sweep *= -1
test_sweep = stools.ts(sweep,56,58.0)

# %%
plot(test_sweep[:500])
plot(stools.get_low_filter(test_sweep,5000)[:500])
display(gcf())

# %%
pp = {'spk_pool_thresh':10.0,
               'spk_window_left' : 25,
               'spk_window_right' : 20,
               'spk_pool_filter_window' : 55}

tp = stools.get_spike_pool(test_sweep,
                      thresh = pp['spk_pool_thresh'],
                      wl = pp['spk_window_left'],
                      wr = pp['spk_window_right'],
                      filter_window = pp['spk_pool_filter_window'])

# %%
plot(test_sweep.times,test_sweep,color = 'k')
from scipy.signal import medfilt
detrend = np.array(test_sweep)-medfilt(test_sweep,pp['spk_pool_filter_window'])
plot(test_sweep.times,detrend,color = 'r')
o = [plot(wf.times,wf,color = 'b',alpha = 0.5,lw = 10) for wf in tp.waveforms]

# %%
fly.signals['AMsysCh1'] = tmp_signal
fly.pool_params = pp

# %%
fly.pool_params = pp

# %%
fly.extract_spike_pool()
fly.process_wb_signals()
# Out:
# calculating flight mask
# calculating stroke phase
# calculating wb reference features
# re-wraping phase
# calculating stroke amplitudes
# updating processed_signals dict

# %%
sp = fly.processed_signals['spike_pool']
phases = fly.processed_signals['wb_phase']
times = fly.signals['LeftWing'].times
fly.processed_signals['spk_phases'] = stools.calc_spike_phases(sp,phases,times)
fly.processed_signals['spk_wbs'] = stools.calc_spike_wbs(sp,fly.processed_signals['wb_flips'],times)

# %%
null_mask = ones_like(sp)

# %%
pca_0 = srtr.PCATransform(sp,null_mask,defaults.pca_trans)
pca_0.transform()

km_settings = {'kmeans_nc':2,'init':'k-means++'}
km_0 = srtr.KMeansCluster(sp,null_mask,pca_0.trnsmtrx,km_settings)
km_0.select()
#hist(p2p_0.trnsmtrx[:,1],bins = 100)
sview.plot_clusters(sp,km_0)
display(gcf())

# %%
mask_00 = km_0.mask_from_labels('0')
mask_01 = km_0.mask_from_labels('1')
sview.plot_select_trains(sp,[mask_00,mask_01])

# %%
mdt_00 = srtr.MedTrans(sp,mask_00,{'trans_dims':1})
mdt_00.transform()
th_00 = srtr.ThreshSelector(sp,mask_00,mdt_00.trnsmtrx,km_settings)
thresh = 280 #np.percentile(mdt_00.trnsmtrx,90)
th_00.select(thresh)
sview.plot_clusters(sp,th_00)
display(gcf())

# %%
mask_000 = th_00.mask_from_labels('0')
mask_001 = th_00.mask_from_labels('1')
sview.plot_select_trains(sp,[mask_00,mask_000,mask_001])

# %%
fly.processed_signals['spike_mask']  = mask_000

# %%
sig_slice = slice(0,10)
e_sweeps = stools.get_trials(fly,2,5,sig_slice,'AMsysCh1')
spks = stools.get_trials(fly,2,5,sig_slice,'spike_pool')
spk_phases = [x.annotations['spk_phases'] for x in spks]
spk_masks = [x.annotations['spike_mask'] for x in spks]
spk_wb_idxs = [x.annotations['spk_wbs'] for x in spks]
###
contra_amp = stools.get_trials(fly,2,5,sig_slice,'RightAmp')
contra_wing = stools.get_trials(fly,2,5,sig_slice,'RightWing')

ipsi_amp = stools.get_trials(fly,2,5,sig_slice,'LeftAmp')
ipsi_wing = stools.get_trials(fly,2,5,sig_slice,'LeftWing')
#####

l_m_r = stools.get_trials(fly,2,5,sig_slice,'L_m_R')
l_m_r = [x*-1 for x in l_m_r]

x_pos = stools.get_trials(fly,2,5,sig_slice,'Xpos')
wb_phases = stools.get_trials(fly,2,5,sig_slice,'wb_phase')

flight_masks = stools.get_trials(fly,2,5,sig_slice,'flight_mask')

full_flights = [x for x in range(len(flight_masks)) if not(np.mean(flight_masks[x]))]

# %%
spk_rasters = stools.extract_cl_spike_rasters(fly,
                                     -0.08,
                                     0.02,
                                     e_sweeps,
                                     spks,
                                     spk_phases,
                                     spk_masks,
                                     spk_wb_idxs,
                                     full_flights)

# %%
for rstr in spk_rasters:
    plot(rstr['f_spk_times'],rstr['f_spk_phases'],'o',color = 'k',alpha = 0.2)

# %%
fly.save_data('flydata_B1.cpkl')

# %%
pca_00 = srtr.PCATransform(sp,mask_00,defaults.pca_trans)
pca_00.transform()
#th_00 = srtr.ThreshSelector(sp,mask_00,pcp_00.trnsmtrx,{})
#thresh = 0.0
#th_00.select(thresh)
#print th_00.collection_ind()
km_settings = {'kmeans_nc':2,'init':'k-means++'}
km_00 = srtr.KMeansCluster(sp,mask_00,pca_00.trnsmtrx,km_settings)
km_00.select()
#hist(p2p_0.trnsmtrx[:,1],bins = 100)
sview.plot_clusters(sp,km_00)
display(gcf())

# %%
mask_000 = km_00.mask_from_labels('0')
mask_001 = km_00.mask_from_labels('1')
sview.plot_select_trains(sp,[mask_01,mask_000,mask_001])

# %%
hist(p2p_00.trnsmtrx[:,1],bins = 100,normed = True)
# Out:
# (array([  4.86805034e-04,   1.85449537e-04,   2.54993113e-04,
#          3.47717881e-04,   2.31811921e-04,   0.00000000e+00,
#          1.85449537e-04,   2.78174305e-04,   2.54993113e-04,
#          6.95435762e-05,   6.95435762e-05,   0.00000000e+00,
#          2.31811921e-05,   2.31811921e-05,   2.31811921e-05,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   9.27247683e-05,
#          1.62268345e-04,   1.39087152e-04,   0.00000000e+00,
#          2.31811921e-05,   2.31811921e-05,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          1.43027955e-02,   1.08951603e-03,   1.08951603e-03,
#          1.64586464e-03,   1.25178437e-03,   0.00000000e+00,
#          1.08951603e-03,   6.95435762e-04,   8.34522915e-04,
#          6.95435762e-04,   1.01997245e-03,   0.00000000e+00,
#          1.55313987e-03,   1.46041510e-03,   1.62268345e-04,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          1.39087152e-04,   9.27247683e-04,   1.18687703e-02,
#          1.98036924e-01,   0.00000000e+00,   6.08483111e-01,
#          3.15704655e-01,   2.15585086e-02,   1.69222702e-03,
#          3.70899073e-04,   0.00000000e+00,   1.15905960e-04,
#          2.08630729e-04,   6.95435762e-05,   1.15905960e-04,
#          3.24536689e-04,   0.00000000e+00,   4.17261457e-04,
#          1.41405272e-03,   2.36448159e-03,   2.38766278e-03,
#          2.17903206e-03,   0.00000000e+00,   4.98395630e-03,
#          3.24536689e-04,   3.47717881e-04,   3.47717881e-04,
#          2.54993113e-04,   0.00000000e+00,   1.85449537e-04,
#          2.31811921e-05,   0.00000000e+00,   0.00000000e+00,
#          2.31811921e-05,   0.00000000e+00,   0.00000000e+00,
#          9.27247683e-05,   4.63623842e-05,   0.00000000e+00,
#          4.63623842e-05]),
#  array([ -4.40000000e+01,  -4.31700000e+01,  -4.23400000e+01,
#         -4.15100000e+01,  -4.06800000e+01,  -3.98500000e+01,
#         -3.90200000e+01,  -3.81900000e+01,  -3.73600000e+01,
#         -3.65300000e+01,  -3.57000000e+01,  -3.48700000e+01,
#         -3.40400000e+01,  -3.32100000e+01,  -3.23800000e+01,
#         -3.15500000e+01,  -3.07200000e+01,  -2.98900000e+01,
#         -2.90600000e+01,  -2.82300000e+01,  -2.74000000e+01,
#         -2.65700000e+01,  -2.57400000e+01,  -2.49100000e+01,
#         -2.40800000e+01,  -2.32500000e+01,  -2.24200000e+01,
#         -2.15900000e+01,  -2.07600000e+01,  -1.99300000e+01,
#         -1.91000000e+01,  -1.82700000e+01,  -1.74400000e+01,
#         -1.66100000e+01,  -1.57800000e+01,  -1.49500000e+01,
#         -1.41200000e+01,  -1.32900000e+01,  -1.24600000e+01,
#         -1.16300000e+01,  -1.08000000e+01,  -9.97000000e+00,
#         -9.14000000e+00,  -8.31000000e+00,  -7.48000000e+00,
#         -6.65000000e+00,  -5.82000000e+00,  -4.99000000e+00,
#         -4.16000000e+00,  -3.33000000e+00,  -2.50000000e+00,
#         -1.67000000e+00,  -8.40000000e-01,  -1.00000000e-02,
#          8.20000000e-01,   1.65000000e+00,   2.48000000e+00,
#          3.31000000e+00,   4.14000000e+00,   4.97000000e+00,
#          5.80000000e+00,   6.63000000e+00,   7.46000000e+00,
#          8.29000000e+00,   9.12000000e+00,   9.95000000e+00,
#          1.07800000e+01,   1.16100000e+01,   1.24400000e+01,
#          1.32700000e+01,   1.41000000e+01,   1.49300000e+01,
#          1.57600000e+01,   1.65900000e+01,   1.74200000e+01,
#          1.82500000e+01,   1.90800000e+01,   1.99100000e+01,
#          2.07400000e+01,   2.15700000e+01,   2.24000000e+01,
#          2.32300000e+01,   2.40600000e+01,   2.48900000e+01,
#          2.57200000e+01,   2.65500000e+01,   2.73800000e+01,
#          2.82100000e+01,   2.90400000e+01,   2.98700000e+01,
#          3.07000000e+01,   3.15300000e+01,   3.23600000e+01,
#          3.31900000e+01,   3.40200000e+01,   3.48500000e+01,
#          3.56800000e+01,   3.65100000e+01,   3.73400000e+01,
#          3.81700000e+01,   3.90000000e+01]),
#  <a list of 100 Patch objects>)

# %%
mask_01 = km_0.mask_from_labels('0')
mask_00 = km_0.mask_from_labels('1')
sview.plot_select_trains(sp,[mask_00,mask_01])

# %%
f = figure()
ax = Axes3D(f)
ax.scatter(pca_0.trnsmtrx[:10000,0],pca_0.trnsmtrx[:10000,1],pca_0.trnsmtrx[:10000,2])
