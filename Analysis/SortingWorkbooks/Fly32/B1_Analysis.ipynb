# %%
from pylab import *
from sklearn import decomposition
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import random
import sys
from sklearn.cluster import KMeans

analysis_lib = '/Users/psilentp/Documents/Projects/NewFlyland/Analysis/'
sys.path.append(analysis_lib)

import flyphys as fph
import defaults
import sorters as srtr
import sorter_view as sview

dataroot = '/Users/psilentp/Dropbox/Data/LeftRight/'

# %%
fly = fph.get_fly_in_rootdir(dataroot,32,0,rec_location = 'B1')
fly_cntrlr = fph.FlyController(fly)

# %%
import signal_tools as stools
tmp_signal = stools.get_low_filter(fly.signals['AMsysCh1'],5000)
sweep = tmp_signal
sweep *= -1
test_sweep = stools.ts(sweep,52,54.0)
plot(test_sweep[:500])
plot(stools.get_low_filter(test_sweep,5000)[:500])
display(gcf())

# %%
pp = {'spk_pool_thresh':50,
               'spk_window_left' : 25,
               'spk_window_right' : 20,
               'spk_pool_filter_window' : 35}

tp = stools.get_spike_pool(test_sweep,
                      thresh = pp['spk_pool_thresh'],
                      wl = pp['spk_window_left'],
                      wr = pp['spk_window_right'],
                      filter_window = pp['spk_pool_filter_window'])

# %%
plot(test_sweep.times,test_sweep,color = 'k')
from scipy.signal import medfilt
detrend = np.array(test_sweep)-medfilt(test_sweep,pp['spk_pool_filter_window'])
plot(test_sweep.times,detrend,color = 'r')
o = [plot(wf.times,wf,color = 'b',alpha = 0.5,lw = 10) for wf in tp.waveforms]

# %%
fly.signals['AMsysCh1'] = tmp_signal
fly.pool_params = pp

# %%
fly.extract_spike_pool()
fly.process_wb_signals()
# Out:
# calculating flight mask
# calculating stroke phase
# calculating wb reference features
# re-wraping phase
# calculating stroke amplitudes
# updating processed_signals dict

# %%
sp = fly.processed_signals['spike_pool']
phases = fly.processed_signals['wb_phase']
times = fly.signals['LeftWing'].times
fly.processed_signals['spk_phases'] = stools.calc_spike_phases(sp,phases,times)
fly.processed_signals['spk_wbs'] = stools.calc_spike_wbs(sp,fly.processed_signals['wb_flips'],times)

# %%
null_mask = ones_like(sp)

# %%
mdt_0 = srtr.MedTrans(sp,null_mask,{'trans_dims':1})
mdt_0.transform()
th_0 = srtr.ThreshSelector(sp,null_mask,mdt_0.trnsmtrx,km_settings)
thresh = 950 #np.percentile(mdt_00.trnsmtrx,90)
th_0.select(thresh)
sview.plot_clusters(sp,th_0)
display(gcf())

# %%
mask_00 = th_0.mask_from_labels('0')
mask_01 = th_0.mask_from_labels('1')
sview.plot_select_trains(sp,[mask_00,mask_01])

# %%
fly.processed_signals['spike_mask']  = mask_00

# %%
fly.save_data('flydata_B1.cpkl')

# %%
pca_0 = srtr.PCATransform(sp,null_mask,defaults.pca_trans)
pca_0.transform()
km_settings = {'kmeans_nc':2,'init':'k-means++'}
km_0 = srtr.KMeansCluster(sp,null_mask,pca_0.trnsmtrx,km_settings)
km_0.select()
sview.plot_clusters(sp,km_0)
display(gcf())

# %%
mask_00 = km_0.mask_from_labels('0')
mask_01 = km_0.mask_from_labels('1')
sview.plot_select_trains(sp,[mask_00,mask_01])

# %%
mask_000 = th_00.mask_from_labels('0')
mask_001 = th_00.mask_from_labels('1')
sview.plot_select_trains(sp,[mask_000,mask_001])

# %%
pca_00 = srtr.PCATransform(sp,mask_00,defaults.pca_trans)
pca_00.transform()
km_settings = {'kmeans_nc':2,'init':'k-means++'}
km_00 = srtr.KMeansCluster(sp,mask_00,pca_00.trnsmtrx,km_settings)
km_00.select()
sview.plot_clusters(sp,km_00)
display(gcf())

# %%
mask_000 = km_00.mask_from_labels('0')
mask_001 = km_00.mask_from_labels('1')
sview.plot_select_trains(sp,[mask_000,mask_001])

# %%
shape(fly.processed_signals['spike_pool'])
# Out:
# (54373,)

# %%
[plot(x.times,x) for x,m in zip(fly.processed_signals['spike_pool'].waveforms,mask_0000) if m]
# Out:
# [[<matplotlib.lines.Line2D at 0x12388e6d0>],
#  [<matplotlib.lines.Line2D at 0x12388ed50>],
#  [<matplotlib.lines.Line2D at 0x123892350>],
#  [<matplotlib.lines.Line2D at 0x123892990>],
#  [<matplotlib.lines.Line2D at 0x1238b2090>],
#  [<matplotlib.lines.Line2D at 0x1238b2650>],
#  [<matplotlib.lines.Line2D at 0x1238b2c90>],
#  [<matplotlib.lines.Line2D at 0x120776790>],
#  [<matplotlib.lines.Line2D at 0x123881950>],
#  [<matplotlib.lines.Line2D at 0x123894050>],
#  [<matplotlib.lines.Line2D at 0x123894610>],
#  [<matplotlib.lines.Line2D at 0x120770ad0>],
#  [<matplotlib.lines.Line2D at 0x120770610>],
#  [<matplotlib.lines.Line2D at 0x120776710>],
#  [<matplotlib.lines.Line2D at 0x123881450>],
#  [<matplotlib.lines.Line2D at 0x1238a5190>],
#  [<matplotlib.lines.Line2D at 0x1238a57d0>],
#  [<matplotlib.lines.Line2D at 0x1238a5e10>],
#  [<matplotlib.lines.Line2D at 0x123887490>],
#  [<matplotlib.lines.Line2D at 0x123887ad0>],
#  [<matplotlib.lines.Line2D at 0x1238b7150>],
#  [<matplotlib.lines.Line2D at 0x123894c50>],
#  [<matplotlib.lines.Line2D at 0x1238b7dd0>],
#  [<matplotlib.lines.Line2D at 0x1238ab450>],
#  [<matplotlib.lines.Line2D at 0x1238aba90>],
#  [<matplotlib.lines.Line2D at 0x1238be110>],
#  [<matplotlib.lines.Line2D at 0x1238be750>],
#  [<matplotlib.lines.Line2D at 0x1238bed90>],
#  [<matplotlib.lines.Line2D at 0x1238b78d0>],
#  [<matplotlib.lines.Line2D at 0x1238b9a50>],
#  [<matplotlib.lines.Line2D at 0x1238970d0>],
#  [<matplotlib.lines.Line2D at 0x123897710>],
#  [<matplotlib.lines.Line2D at 0x123897d50>],
#  [<matplotlib.lines.Line2D at 0x1238b33d0>],
#  [<matplotlib.lines.Line2D at 0x1238b3a10>],
#  [<matplotlib.lines.Line2D at 0x1238b9550>],
#  [<matplotlib.lines.Line2D at 0x1211ab6d0>],
#  [<matplotlib.lines.Line2D at 0x1211abd10>],
#  [<matplotlib.lines.Line2D at 0x1211a6390>],
#  [<matplotlib.lines.Line2D at 0x1211a69d0>],
#  [<matplotlib.lines.Line2D at 0x1211b3050>],
#  [<matplotlib.lines.Line2D at 0x1211b3690>],
#  [<matplotlib.lines.Line2D at 0x1211ab1d0>],
#  [<matplotlib.lines.Line2D at 0x12118e350>],
#  [<matplotlib.lines.Line2D at 0x12118e990>],
#  [<matplotlib.lines.Line2D at 0x1211b1090>],
#  [<matplotlib.lines.Line2D at 0x1211b1650>],
#  [<matplotlib.lines.Line2D at 0x1211b1c90>],
#  [<matplotlib.lines.Line2D at 0x1211b5310>],
#  [<matplotlib.lines.Line2D at 0x1211b3e10>],
#  [<matplotlib.lines.Line2D at 0x12118d050>],
#  [<matplotlib.lines.Line2D at 0x12118d610>],
#  [<matplotlib.lines.Line2D at 0x12118dc50>],
#  [<matplotlib.lines.Line2D at 0x1211902d0>],
#  [<matplotlib.lines.Line2D at 0x121190910>],
#  [<matplotlib.lines.Line2D at 0x121190f50>],
#  [<matplotlib.lines.Line2D at 0x1211b5a90>],
#  [<matplotlib.lines.Line2D at 0x121183c10>],
#  [<matplotlib.lines.Line2D at 0x1211aa290>],
#  [<matplotlib.lines.Line2D at 0x1211aa8d0>],
#  [<matplotlib.lines.Line2D at 0x1211aaf10>],
#  [<matplotlib.lines.Line2D at 0x1211ac590>],
#  [<matplotlib.lines.Line2D at 0x1211acbd0>],
#  [<matplotlib.lines.Line2D at 0x121183710>],
#  [<matplotlib.lines.Line2D at 0x1211be890>],
#  [<matplotlib.lines.Line2D at 0x1211beed0>],
#  [<matplotlib.lines.Line2D at 0x12118a550>],
#  [<matplotlib.lines.Line2D at 0x12118ab90>],
#  [<matplotlib.lines.Line2D at 0x1211a5210>],
#  [<matplotlib.lines.Line2D at 0x1211a5850>],
#  [<matplotlib.lines.Line2D at 0x1211a5e90>],
#  [<matplotlib.lines.Line2D at 0x12119b510>],
#  [<matplotlib.lines.Line2D at 0x12119bb50>],
#  [<matplotlib.lines.Line2D at 0x12119d1d0>],
#  [<matplotlib.lines.Line2D at 0x12119d810>],
#  [<matplotlib.lines.Line2D at 0x12119de50>],
#  [<matplotlib.lines.Line2D at 0x1211914d0>],
#  [<matplotlib.lines.Line2D at 0x1211a5fd0>],
#  [<matplotlib.lines.Line2D at 0x1211a7190>],
#  [<matplotlib.lines.Line2D at 0x1211a77d0>],
#  [<matplotlib.lines.Line2D at 0x1211a7e10>],
#  [<matplotlib.lines.Line2D at 0x1398c3490>],
#  [<matplotlib.lines.Line2D at 0x1398c3ad0>],
#  [<matplotlib.lines.Line2D at 0x1398d1150>],
#  [<matplotlib.lines.Line2D at 0x121191c50>],
#  [<matplotlib.lines.Line2D at 0x1398d1dd0>],
#  [<matplotlib.lines.Line2D at 0x1398f3450>],
#  [<matplotlib.lines.Line2D at 0x1398f3a90>],
#  [<matplotlib.lines.Line2D at 0x1398ba110>],
#  [<matplotlib.lines.Line2D at 0x1398ba750>],
#  [<matplotlib.lines.Line2D at 0x1398bad90>],
#  [<matplotlib.lines.Line2D at 0x1398d18d0>],
#  [<matplotlib.lines.Line2D at 0x1398eaa50>],
#  [<matplotlib.lines.Line2D at 0x1398df0d0>],
#  [<matplotlib.lines.Line2D at 0x1398df710>],
#  [<matplotlib.lines.Line2D at 0x1398dfd50>],
#  [<matplotlib.lines.Line2D at 0x1398e13d0>],
#  [<matplotlib.lines.Line2D at 0x1398e1a10>],
#  [<matplotlib.lines.Line2D at 0x1398ea550>],
#  [<matplotlib.lines.Line2D at 0x1398be6d0>],
#  [<matplotlib.lines.Line2D at 0x1398bed10>],
#  [<matplotlib.lines.Line2D at 0x1398ec390>],
#  [<matplotlib.lines.Line2D at 0x1398ec9d0>],
#  [<matplotlib.lines.Line2D at 0x1398bb050>],
#  [<matplotlib.lines.Line2D at 0x1398bb690>],
#  [<matplotlib.lines.Line2D at 0x1398be1d0>],
#  [<matplotlib.lines.Line2D at 0x1398f0350>],
#  [<matplotlib.lines.Line2D at 0x1398f0990>],
#  [<matplotlib.lines.Line2D at 0x1398d6090>],
#  [<matplotlib.lines.Line2D at 0x1398d6650>],
#  [<matplotlib.lines.Line2D at 0x1398d6c90>],
#  [<matplotlib.lines.Line2D at 0x1398ee310>],
#  [<matplotlib.lines.Line2D at 0x1398bbe10>],
#  [<matplotlib.lines.Line2D at 0x1398d2050>],
#  [<matplotlib.lines.Line2D at 0x1398d2610>],
#  [<matplotlib.lines.Line2D at 0x1398d2c50>],
#  [<matplotlib.lines.Line2D at 0x1398bd2d0>],
#  [<matplotlib.lines.Line2D at 0x1398bd910>],
#  [<matplotlib.lines.Line2D at 0x1398bdf50>],
#  [<matplotlib.lines.Line2D at 0x1398eea90>],
#  [<matplotlib.lines.Line2D at 0x1398e4c10>],
#  [<matplotlib.lines.Line2D at 0x1398c1290>],
#  [<matplotlib.lines.Line2D at 0x1398c18d0>],
#  [<matplotlib.lines.Line2D at 0x1398c1f10>],
#  [<matplotlib.lines.Line2D at 0x120d45590>],
#  [<matplotlib.lines.Line2D at 0x120d45bd0>],
#  [<matplotlib.lines.Line2D at 0x1398e4710>],
#  [<matplotlib.lines.Line2D at 0x120d5d890>],
#  [<matplotlib.lines.Line2D at 0x120d5ded0>],
#  [<matplotlib.lines.Line2D at 0x120d54550>],
#  [<matplotlib.lines.Line2D at 0x120d54b90>],
#  [<matplotlib.lines.Line2D at 0x120d3f210>],
#  [<matplotlib.lines.Line2D at 0x120d3f850>],
#  [<matplotlib.lines.Line2D at 0x120d3fe90>],
#  [<matplotlib.lines.Line2D at 0x120d2a510>],
#  [<matplotlib.lines.Line2D at 0x120d2ab50>],
#  [<matplotlib.lines.Line2D at 0x120d621d0>],
#  [<matplotlib.lines.Line2D at 0x120d62810>],
#  [<matplotlib.lines.Line2D at 0x120d62e50>],
#  [<matplotlib.lines.Line2D at 0x120d3a4d0>],
#  [<matplotlib.lines.Line2D at 0x120d3ffd0>],
#  [<matplotlib.lines.Line2D at 0x120d3e190>],
#  [<matplotlib.lines.Line2D at 0x120d3e7d0>],
#  [<matplotlib.lines.Line2D at 0x120d3ee10>],
#  [<matplotlib.lines.Line2D at 0x120d3b490>],
#  [<matplotlib.lines.Line2D at 0x120d3bad0>],
#  [<matplotlib.lines.Line2D at 0x120d52150>],
#  [<matplotlib.lines.Line2D at 0x120d3ac50>],
#  [<matplotlib.lines.Line2D at 0x120d52dd0>],
#  [<matplotlib.lines.Line2D at 0x120d4f450>],
#  [<matplotlib.lines.Line2D at 0x120d4fa90>],
#  [<matplotlib.lines.Line2D at 0x120d46110>],
#  [<matplotlib.lines.Line2D at 0x120d46750>],
#  [<matplotlib.lines.Line2D at 0x120d46d90>],
#  [<matplotlib.lines.Line2D at 0x120d528d0>],
#  [<matplotlib.lines.Line2D at 0x120d37a50>],
#  [<matplotlib.lines.Line2D at 0x120d600d0>],
#  [<matplotlib.lines.Line2D at 0x120d60710>],
#  [<matplotlib.lines.Line2D at 0x120d60d50>],
#  [<matplotlib.lines.Line2D at 0x120d5e3d0>],
#  [<matplotlib.lines.Line2D at 0x120d5ea10>],
#  [<matplotlib.lines.Line2D at 0x120d37550>],
#  [<matplotlib.lines.Line2D at 0x120d326d0>],
#  [<matplotlib.lines.Line2D at 0x120d32d10>],
#  [<matplotlib.lines.Line2D at 0x120d64390>],
#  [<matplotlib.lines.Line2D at 0x120d649d0>],
#  [<matplotlib.lines.Line2D at 0x120d2e050>],
#  [<matplotlib.lines.Line2D at 0x120d2e690>],
#  [<matplotlib.lines.Line2D at 0x120d321d0>],
#  [<matplotlib.lines.Line2D at 0x120a8a350>],
#  [<matplotlib.lines.Line2D at 0x120a8a990>],
#  [<matplotlib.lines.Line2D at 0x120aa8090>],
#  [<matplotlib.lines.Line2D at 0x120aa8650>],
#  [<matplotlib.lines.Line2D at 0x120aa8c90>],
#  [<matplotlib.lines.Line2D at 0x120aa6310>],
#  [<matplotlib.lines.Line2D at 0x120d2ee10>],
#  [<matplotlib.lines.Line2D at 0x120a90050>],
#  [<matplotlib.lines.Line2D at 0x120a90610>],
#  [<matplotlib.lines.Line2D at 0x120a90c50>],
#  [<matplotlib.lines.Line2D at 0x120a7c2d0>],
#  [<matplotlib.lines.Line2D at 0x120a7c910>],
#  [<matplotlib.lines.Line2D at 0x120a7cf50>],
#  [<matplotlib.lines.Line2D at 0x120aa6a90>],
#  [<matplotlib.lines.Line2D at 0x120a7dc10>],
#  [<matplotlib.lines.Line2D at 0x120a8f290>],
#  [<matplotlib.lines.Line2D at 0x120a8f8d0>],
#  [<matplotlib.lines.Line2D at 0x120a8ff10>],
#  [<matplotlib.lines.Line2D at 0x120a98590>],
#  [<matplotlib.lines.Line2D at 0x120a98bd0>],
#  [<matplotlib.lines.Line2D at 0x120a7d710>],
#  [<matplotlib.lines.Line2D at 0x120ab4890>],
#  [<matplotlib.lines.Line2D at 0x120ab4ed0>],
#  [<matplotlib.lines.Line2D at 0x120a9d550>],
#  [<matplotlib.lines.Line2D at 0x120a9db90>],
#  [<matplotlib.lines.Line2D at 0x120a8e210>],
#  [<matplotlib.lines.Line2D at 0x120a8e850>],
#  [<matplotlib.lines.Line2D at 0x120a8ee90>],
#  [<matplotlib.lines.Line2D at 0x120a99510>],
#  [<matplotlib.lines.Line2D at 0x120a99b50>],
#  [<matplotlib.lines.Line2D at 0x120a921d0>],
#  [<matplotlib.lines.Line2D at 0x120a92810>],
#  [<matplotlib.lines.Line2D at 0x120a92e50>],
#  [<matplotlib.lines.Line2D at 0x120aa24d0>],
#  [<matplotlib.lines.Line2D at 0x120a8efd0>],
#  [<matplotlib.lines.Line2D at 0x120a83190>],
#  [<matplotlib.lines.Line2D at 0x120a837d0>],
#  [<matplotlib.lines.Line2D at 0x120a83e10>],
#  [<matplotlib.lines.Line2D at 0x120a80490>],
#  [<matplotlib.lines.Line2D at 0x120a80ad0>],
#  [<matplotlib.lines.Line2D at 0x120a8c150>],
#  [<matplotlib.lines.Line2D at 0x120aa2c50>],
#  [<matplotlib.lines.Line2D at 0x120a8cdd0>],
#  [<matplotlib.lines.Line2D at 0x120951450>],
#  [<matplotlib.lines.Line2D at 0x120951a90>],
#  [<matplotlib.lines.Line2D at 0x120966110>],
#  [<matplotlib.lines.Line2D at 0x120966750>],
#  [<matplotlib.lines.Line2D at 0x120966d90>],
#  [<matplotlib.lines.Line2D at 0x120a8c8d0>],
#  [<matplotlib.lines.Line2D at 0x1209739d0>],
#  [<matplotlib.lines.Line2D at 0x1209530d0>],
#  [<matplotlib.lines.Line2D at 0x120953710>],
#  [<matplotlib.lines.Line2D at 0x120953d50>],
#  [<matplotlib.lines.Line2D at 0x1209503d0>],
#  [<matplotlib.lines.Line2D at 0x120950a10>],
#  [<matplotlib.lines.Line2D at 0x1209731d0>],
#  [<matplotlib.lines.Line2D at 0x12097b6d0>],
#  [<matplotlib.lines.Line2D at 0x12097bd10>],
#  [<matplotlib.lines.Line2D at 0x12098b390>],
#  [<matplotlib.lines.Line2D at 0x12098b9d0>],
#  [<matplotlib.lines.Line2D at 0x120981050>],
#  [<matplotlib.lines.Line2D at 0x120981690>],
#  [<matplotlib.lines.Line2D at 0x12097b1d0>],
#  [<matplotlib.lines.Line2D at 0x120967350>],
#  [<matplotlib.lines.Line2D at 0x120967990>],
#  [<matplotlib.lines.Line2D at 0x120964090>],
#  [<matplotlib.lines.Line2D at 0x120964650>],
#  [<matplotlib.lines.Line2D at 0x120964c90>],
#  [<matplotlib.lines.Line2D at 0x120952310>],
#  [<matplotlib.lines.Line2D at 0x120981e10>],
#  [<matplotlib.lines.Line2D at 0x120954050>],
#  [<matplotlib.lines.Line2D at 0x120954610>],
#  [<matplotlib.lines.Line2D at 0x120954c50>],
#  [<matplotlib.lines.Line2D at 0x12094d2d0>],
#  [<matplotlib.lines.Line2D at 0x12094d910>],
#  [<matplotlib.lines.Line2D at 0x12094df50>],
#  [<matplotlib.lines.Line2D at 0x120952a90>],
#  [<matplotlib.lines.Line2D at 0x12094ec10>],
#  [<matplotlib.lines.Line2D at 0x12095d290>],
#  [<matplotlib.lines.Line2D at 0x12095d8d0>],
#  [<matplotlib.lines.Line2D at 0x12095df10>],
#  [<matplotlib.lines.Line2D at 0x120977590>],
#  [<matplotlib.lines.Line2D at 0x120977bd0>],
#  [<matplotlib.lines.Line2D at 0x12094e710>],
#  [<matplotlib.lines.Line2D at 0x120975890>],
#  [<matplotlib.lines.Line2D at 0x120975ed0>],
#  [<matplotlib.lines.Line2D at 0x120980550>],
#  [<matplotlib.lines.Line2D at 0x120980b90>],
#  [<matplotlib.lines.Line2D at 0x121175210>],
#  [<matplotlib.lines.Line2D at 0x121175850>],
#  [<matplotlib.lines.Line2D at 0x121175e90>],
#  [<matplotlib.lines.Line2D at 0x121144510>],
#  [<matplotlib.lines.Line2D at 0x121144b50>],
#  [<matplotlib.lines.Line2D at 0x1211661d0>],
#  [<matplotlib.lines.Line2D at 0x121166810>],
#  [<matplotlib.lines.Line2D at 0x121166e50>],
#  [<matplotlib.lines.Line2D at 0x12117f4d0>],
#  [<matplotlib.lines.Line2D at 0x121175fd0>],
#  [<matplotlib.lines.Line2D at 0x121148190>],
#  [<matplotlib.lines.Line2D at 0x1211487d0>],
#  [<matplotlib.lines.Line2D at 0x121148e10>],
#  [<matplotlib.lines.Line2D at 0x12117e490>],
#  [<matplotlib.lines.Line2D at 0x12117ead0>],
#  [<matplotlib.lines.Line2D at 0x12115f150>],
#  [<matplotlib.lines.Line2D at 0x12117fc50>],
#  [<matplotlib.lines.Line2D at 0x12115fdd0>],
#  [<matplotlib.lines.Line2D at 0x12115c450>],
#  [<matplotlib.lines.Line2D at 0x12115ca90>],
#  [<matplotlib.lines.Line2D at 0x121170110>],
#  [<matplotlib.lines.Line2D at 0x121170750>],
#  [<matplotlib.lines.Line2D at 0x121170d90>],
#  [<matplotlib.lines.Line2D at 0x12115f8d0>],
#  [<matplotlib.lines.Line2D at 0x121159a50>],
#  [<matplotlib.lines.Line2D at 0x12114f0d0>],
#  [<matplotlib.lines.Line2D at 0x12114f710>],
#  [<matplotlib.lines.Line2D at 0x12114fd50>],
#  [<matplotlib.lines.Line2D at 0x12114e3d0>],
#  [<matplotlib.lines.Line2D at 0x12114ea10>],
#  [<matplotlib.lines.Line2D at 0x121159550>],
#  [<matplotlib.lines.Line2D at 0x1211546d0>],
#  [<matplotlib.lines.Line2D at 0x121154d10>],
#  [<matplotlib.lines.Line2D at 0x12116b390>],
#  [<matplotlib.lines.Line2D at 0x12116b9d0>],
#  [<matplotlib.lines.Line2D at 0x121156050>],
#  [<matplotlib.lines.Line2D at 0x121156690>],
#  [<matplotlib.lines.Line2D at 0x1211541d0>],
#  [<matplotlib.lines.Line2D at 0x12114c350>],
#  [<matplotlib.lines.Line2D at 0x12114c990>],
#  [<matplotlib.lines.Line2D at 0x121177090>],
#  [<matplotlib.lines.Line2D at 0x121177650>],
#  [<matplotlib.lines.Line2D at 0x121177c90>],
#  [<matplotlib.lines.Line2D at 0x120b76310>],
#  [<matplotlib.lines.Line2D at 0x121156e10>],
#  [<matplotlib.lines.Line2D at 0x120b73050>],
#  [<matplotlib.lines.Line2D at 0x120b73610>],
#  [<matplotlib.lines.Line2D at 0x120b73c50>],
#  [<matplotlib.lines.Line2D at 0x120ba72d0>],
#  [<matplotlib.lines.Line2D at 0x120ba7910>],
#  [<matplotlib.lines.Line2D at 0x120ba7f50>],
#  [<matplotlib.lines.Line2D at 0x120b76a90>],
#  [<matplotlib.lines.Line2D at 0x120b9fc10>],
#  [<matplotlib.lines.Line2D at 0x120b6b290>],
#  [<matplotlib.lines.Line2D at 0x120b6b8d0>],
#  [<matplotlib.lines.Line2D at 0x120b6bf10>],
#  [<matplotlib.lines.Line2D at 0x120b9a590>],
#  [<matplotlib.lines.Line2D at 0x120b9abd0>],
#  [<matplotlib.lines.Line2D at 0x120b9f710>],
#  [<matplotlib.lines.Line2D at 0x120b94890>],
#  [<matplotlib.lines.Line2D at 0x120b94ed0>],
#  [<matplotlib.lines.Line2D at 0x120b95550>],
#  [<matplotlib.lines.Line2D at 0x120b95b90>],
#  [<matplotlib.lines.Line2D at 0x120b8d210>],
#  [<matplotlib.lines.Line2D at 0x120b8d850>],
#  [<matplotlib.lines.Line2D at 0x120b8de90>],
#  [<matplotlib.lines.Line2D at 0x120b91510>],
#  [<matplotlib.lines.Line2D at 0x120b91b50>],
#  [<matplotlib.lines.Line2D at 0x120b851d0>],
#  [<matplotlib.lines.Line2D at 0x120b85810>],
#  [<matplotlib.lines.Line2D at 0x120b85e50>],
#  [<matplotlib.lines.Line2D at 0x120b9c4d0>],
#  [<matplotlib.lines.Line2D at 0x120b8dfd0>],
#  [<matplotlib.lines.Line2D at 0x120b74190>],
#  [<matplotlib.lines.Line2D at 0x120b747d0>],
#  [<matplotlib.lines.Line2D at 0x120b74e10>],
#  [<matplotlib.lines.Line2D at 0x120b6c490>],
#  [<matplotlib.lines.Line2D at 0x120b6cad0>],
#  [<matplotlib.lines.Line2D at 0x120ba9150>],
#  [<matplotlib.lines.Line2D at 0x120b9cc50>],
#  [<matplotlib.lines.Line2D at 0x120ba9dd0>],
#  [<matplotlib.lines.Line2D at 0x120b75450>],
#  [<matplotlib.lines.Line2D at 0x120b75a90>],
#  [<matplotlib.lines.Line2D at 0x120b7c110>],
#  [<matplotlib.lines.Line2D at 0x120b7c750>],
#  [<matplotlib.lines.Line2D at 0x120b7cd90>],
#  [<matplotlib.lines.Line2D at 0x120ba98d0>],
#  [<matplotlib.lines.Line2D at 0x120b8fa50>],
#  [<matplotlib.lines.Line2D at 0x122e200d0>],
#  [<matplotlib.lines.Line2D at 0x122e20710>],
#  [<matplotlib.lines.Line2D at 0x122e20d50>],
#  [<matplotlib.lines.Line2D at 0x122e103d0>],
#  [<matplotlib.lines.Line2D at 0x122e10a10>],
#  [<matplotlib.lines.Line2D at 0x120b8f550>],
#  [<matplotlib.lines.Line2D at 0x122e156d0>],
#  [<matplotlib.lines.Line2D at 0x122e15d10>],
#  [<matplotlib.lines.Line2D at 0x122e29390>],
#  [<matplotlib.lines.Line2D at 0x122e299d0>],
#  [<matplotlib.lines.Line2D at 0x122e36050>],
#  [<matplotlib.lines.Line2D at 0x122e36690>],
#  [<matplotlib.lines.Line2D at 0x122e151d0>],
#  [<matplotlib.lines.Line2D at 0x122e04350>],
#  [<matplotlib.lines.Line2D at 0x122e04990>],
#  [<matplotlib.lines.Line2D at 0x122e07090>],
#  [<matplotlib.lines.Line2D at 0x122e07650>],
#  [<matplotlib.lines.Line2D at 0x122e07c90>],
#  [<matplotlib.lines.Line2D at 0x122e06310>],
#  [<matplotlib.lines.Line2D at 0x122e36e10>],
#  [<matplotlib.lines.Line2D at 0x122e1c050>],
#  [<matplotlib.lines.Line2D at 0x122e1c610>],
#  [<matplotlib.lines.Line2D at 0x122e1cc50>],
#  [<matplotlib.lines.Line2D at 0x122e2b2d0>],
#  [<matplotlib.lines.Line2D at 0x122e2b910>],
#  [<matplotlib.lines.Line2D at 0x122e2bf50>],
#  [<matplotlib.lines.Line2D at 0x122e06a90>],
#  [<matplotlib.lines.Line2D at 0x122e09c10>],
#  [<matplotlib.lines.Line2D at 0x122e1f290>],
#  [<matplotlib.lines.Line2D at 0x122e1f8d0>],
#  [<matplotlib.lines.Line2D at 0x122e1ff10>],
#  [<matplotlib.lines.Line2D at 0x122e0c590>],
#  [<matplotlib.lines.Line2D at 0x122e0cbd0>],
#  [<matplotlib.lines.Line2D at 0x122e09710>],
#  [<matplotlib.lines.Line2D at 0x122e08890>],
#  [<matplotlib.lines.Line2D at 0x122e08ed0>],
#  [<matplotlib.lines.Line2D at 0x122e01550>],
#  [<matplotlib.lines.Line2D at 0x122e01b90>],
#  [<matplotlib.lines.Line2D at 0x122e37210>],
#  [<matplotlib.lines.Line2D at 0x122e37850>],
#  [<matplotlib.lines.Line2D at 0x122e37e90>],
#  [<matplotlib.lines.Line2D at 0x122e3d510>],
#  [<matplotlib.lines.Line2D at 0x122e3db50>],
#  [<matplotlib.lines.Line2D at 0x120dd61d0>],
#  [<matplotlib.lines.Line2D at 0x120dd6810>],
#  [<matplotlib.lines.Line2D at 0x120dd6e50>],
#  [<matplotlib.lines.Line2D at 0x120db94d0>],
#  [<matplotlib.lines.Line2D at 0x122e37fd0>],
#  [<matplotlib.lines.Line2D at 0x120dbc190>],
#  [<matplotlib.lines.Line2D at 0x120dbc7d0>],
#  [<matplotlib.lines.Line2D at 0x120dbce10>],
#  [<matplotlib.lines.Line2D at 0x120db7490>],
#  [<matplotlib.lines.Line2D at 0x120db7ad0>],
#  [<matplotlib.lines.Line2D at 0x120dc8150>],
#  [<matplotlib.lines.Line2D at 0x120db9c50>],
#  [<matplotlib.lines.Line2D at 0x120dc8dd0>],
#  [<matplotlib.lines.Line2D at 0x120de0450>],
#  [<matplotlib.lines.Line2D at 0x120de0a90>],
#  [<matplotlib.lines.Line2D at 0x120de4110>],
#  [<matplotlib.lines.Line2D at 0x120de4750>],
#  [<matplotlib.lines.Line2D at 0x120de4d90>],
#  [<matplotlib.lines.Line2D at 0x120dc88d0>],
#  [<matplotlib.lines.Line2D at 0x120daea50>],
#  [<matplotlib.lines.Line2D at 0x120db50d0>],
#  [<matplotlib.lines.Line2D at 0x120db5710>],
#  [<matplotlib.lines.Line2D at 0x120db5d50>],
#  [<matplotlib.lines.Line2D at 0x120dbf3d0>],
#  [<matplotlib.lines.Line2D at 0x120dbfa10>],
#  [<matplotlib.lines.Line2D at 0x120dae550>],
#  [<matplotlib.lines.Line2D at 0x120dcc6d0>],
#  [<matplotlib.lines.Line2D at 0x120dccd10>],
#  [<matplotlib.lines.Line2D at 0x120db2390>],
#  [<matplotlib.lines.Line2D at 0x120db29d0>],
#  [<matplotlib.lines.Line2D at 0x120daf050>],
#  [<matplotlib.lines.Line2D at 0x120daf690>],
#  [<matplotlib.lines.Line2D at 0x120dcc1d0>],
#  [<matplotlib.lines.Line2D at 0x120dd0350>],
#  [<matplotlib.lines.Line2D at 0x120dd0990>],
#  [<matplotlib.lines.Line2D at 0x120dc6090>],
#  [<matplotlib.lines.Line2D at 0x120dc6650>],
#  [<matplotlib.lines.Line2D at 0x120dc6c90>],
#  [<matplotlib.lines.Line2D at 0x120dce310>],
#  [<matplotlib.lines.Line2D at 0x120dafe10>],
#  [<matplotlib.lines.Line2D at 0x120ddf050>],
#  [<matplotlib.lines.Line2D at 0x120ddf610>],
#  [<matplotlib.lines.Line2D at 0x120ddfc50>],
#  [<matplotlib.lines.Line2D at 0x120db02d0>],
#  [<matplotlib.lines.Line2D at 0x120db0910>],
#  [<matplotlib.lines.Line2D at 0x120db0f50>],
#  [<matplotlib.lines.Line2D at 0x120dcea90>],
#  [<matplotlib.lines.Line2D at 0x1238e4c10>],
#  [<matplotlib.lines.Line2D at 0x1238ea290>],
#  [<matplotlib.lines.Line2D at 0x1238ea8d0>],
#  [<matplotlib.lines.Line2D at 0x1238eaf10>],
#  [<matplotlib.lines.Line2D at 0x1238f2590>],
#  [<matplotlib.lines.Line2D at 0x1238f2bd0>],
#  [<matplotlib.lines.Line2D at 0x1238e4710>],
#  [<matplotlib.lines.Line2D at 0x1238f0890>],
#  [<matplotlib.lines.Line2D at 0x1238f0ed0>],
#  [<matplotlib.lines.Line2D at 0x1238ef550>],
#  [<matplotlib.lines.Line2D at 0x1238efb90>],
#  [<matplotlib.lines.Line2D at 0x1238c5210>],
#  [<matplotlib.lines.Line2D at 0x1238c5850>],
#  [<matplotlib.lines.Line2D at 0x1238c5e90>],
#  [<matplotlib.lines.Line2D at 0x1238c3510>],
#  [<matplotlib.lines.Line2D at 0x1238c3b50>],
#  [<matplotlib.lines.Line2D at 0x1238e11d0>],
#  [<matplotlib.lines.Line2D at 0x1238e1810>],
#  [<matplotlib.lines.Line2D at 0x1238e1e50>],
#  [<matplotlib.lines.Line2D at 0x1238c24d0>],
#  [<matplotlib.lines.Line2D at 0x1238c5fd0>],
#  [<matplotlib.lines.Line2D at 0x1238fe190>],
#  [<matplotlib.lines.Line2D at 0x1238fe7d0>],
#  [<matplotlib.lines.Line2D at 0x1238fee10>],
#  [<matplotlib.lines.Line2D at 0x1238c0490>],
#  [<matplotlib.lines.Line2D at 0x1238c0ad0>],
#  [<matplotlib.lines.Line2D at 0x1238f8150>],
#  [<matplotlib.lines.Line2D at 0x1238c2c50>],
#  [<matplotlib.lines.Line2D at 0x1238f8dd0>],
#  [<matplotlib.lines.Line2D at 0x1238ee450>],
#  [<matplotlib.lines.Line2D at 0x1238eea90>],
#  [<matplotlib.lines.Line2D at 0x1238e0110>],
#  [<matplotlib.lines.Line2D at 0x1238e0750>],
#  [<matplotlib.lines.Line2D at 0x1238e0d90>],
#  [<matplotlib.lines.Line2D at 0x1238f88d0>],
#  [<matplotlib.lines.Line2D at 0x1238eda50>],
#  [<matplotlib.lines.Line2D at 0x1238c90d0>],
#  [<matplotlib.lines.Line2D at 0x1238c9710>],
#  [<matplotlib.lines.Line2D at 0x1238c9d50>],
#  [<matplotlib.lines.Line2D at 0x1238e93d0>],
#  [<matplotlib.lines.Line2D at 0x1238e9a10>],
#  [<matplotlib.lines.Line2D at 0x1238ed550>],
#  [<matplotlib.lines.Line2D at 0x1238cb6d0>],
#  [<matplotlib.lines.Line2D at 0x1238cbd10>],
#  [<matplotlib.lines.Line2D at 0x139db1390>],
#  [<matplotlib.lines.Line2D at 0x139db19d0>],
#  [<matplotlib.lines.Line2D at 0x139d8f050>],
#  [<matplotlib.lines.Line2D at 0x139d8f690>],
#  [<matplotlib.lines.Line2D at 0x1238cb1d0>],
#  [<matplotlib.lines.Line2D at 0x139d9e350>],
#  [<matplotlib.lines.Line2D at 0x139d9e990>],
#  [<matplotlib.lines.Line2D at 0x139db8090>],
#  [<matplotlib.lines.Line2D at 0x139db8650>],
#  [<matplotlib.lines.Line2D at 0x139db8c90>],
#  [<matplotlib.lines.Line2D at 0x139d91310>],
#  [<matplotlib.lines.Line2D at 0x139d8fe10>],
#  [<matplotlib.lines.Line2D at 0x139dc2050>],
#  [<matplotlib.lines.Line2D at 0x139dc2610>],
#  [<matplotlib.lines.Line2D at 0x139dc2c50>],
#  [<matplotlib.lines.Line2D at 0x139da32d0>],
#  [<matplotlib.lines.Line2D at 0x139da3910>],
#  [<matplotlib.lines.Line2D at 0x139da3f50>],
#  [<matplotlib.lines.Line2D at 0x139d91a90>],
#  [<matplotlib.lines.Line2D at 0x139da5c10>],
#  [<matplotlib.lines.Line2D at 0x139db7290>],
#  [<matplotlib.lines.Line2D at 0x139db78d0>],
#  [<matplotlib.lines.Line2D at 0x139db7f10>],
#  [<matplotlib.lines.Line2D at 0x139d92590>],
#  [<matplotlib.lines.Line2D at 0x139d92bd0>],
#  [<matplotlib.lines.Line2D at 0x139da5710>],
#  [<matplotlib.lines.Line2D at 0x139d96890>],
#  [<matplotlib.lines.Line2D at 0x139d96ed0>],
#  [<matplotlib.lines.Line2D at 0x139d98550>],
#  [<matplotlib.lines.Line2D at 0x139d98b90>],
#  [<matplotlib.lines.Line2D at 0x139da0210>],
#  [<matplotlib.lines.Line2D at 0x139da0850>],
#  [<matplotlib.lines.Line2D at 0x139da0e90>],
#  [<matplotlib.lines.Line2D at 0x139d9f510>],
#  [<matplotlib.lines.Line2D at 0x139d9fb50>],
#  [<matplotlib.lines.Line2D at 0x139da71d0>],
#  [<matplotlib.lines.Line2D at 0x139da7810>],
#  [<matplotlib.lines.Line2D at 0x139da7e50>],
#  [<matplotlib.lines.Line2D at 0x139db54d0>],
#  [<matplotlib.lines.Line2D at 0x139da0fd0>],
#  [<matplotlib.lines.Line2D at 0x139d8c190>],
#  [<matplotlib.lines.Line2D at 0x139d8c7d0>],
#  [<matplotlib.lines.Line2D at 0x139d8ce10>],
#  [<matplotlib.lines.Line2D at 0x16e10c490>],
#  [<matplotlib.lines.Line2D at 0x16e10cad0>],
#  [<matplotlib.lines.Line2D at 0x16e126150>],
#  [<matplotlib.lines.Line2D at 0x139db5c50>],
#  [<matplotlib.lines.Line2D at 0x16e126dd0>],
#  [<matplotlib.lines.Line2D at 0x16e115450>],
#  [<matplotlib.lines.Line2D at 0x16e115a90>],
#  [<matplotlib.lines.Line2D at 0x16e129110>],
#  [<matplotlib.lines.Line2D at 0x16e129750>],
#  [<matplotlib.lines.Line2D at 0x16e129d90>],
#  [<matplotlib.lines.Line2D at 0x16e1268d0>],
#  [<matplotlib.lines.Line2D at 0x16e137a50>],
#  [<matplotlib.lines.Line2D at 0x16e1100d0>],
#  [<matplotlib.lines.Line2D at 0x16e110710>],
#  [<matplotlib.lines.Line2D at 0x16e110d50>],
#  [<matplotlib.lines.Line2D at 0x16e12b3d0>],
#  [<matplotlib.lines.Line2D at 0x16e12ba10>],
#  [<matplotlib.lines.Line2D at 0x16e137550>],
#  [<matplotlib.lines.Line2D at 0x16e1096d0>],
#  [<matplotlib.lines.Line2D at 0x16e109d10>],
#  [<matplotlib.lines.Line2D at 0x16e119390>],
#  [<matplotlib.lines.Line2D at 0x16e1199d0>],
#  [<matplotlib.lines.Line2D at 0x16e114050>],
#  [<matplotlib.lines.Line2D at 0x16e114690>],
#  [<matplotlib.lines.Line2D at 0x16e1091d0>],
#  [<matplotlib.lines.Line2D at 0x16e13f350>],
#  [<matplotlib.lines.Line2D at 0x16e13f990>],
#  [<matplotlib.lines.Line2D at 0x16e10e090>],
#  [<matplotlib.lines.Line2D at 0x16e10e650>],
#  [<matplotlib.lines.Line2D at 0x16e10ec90>],
#  [<matplotlib.lines.Line2D at 0x16e12d310>],
#  [<matplotlib.lines.Line2D at 0x16e114e10>],
#  [<matplotlib.lines.Line2D at 0x16e121050>],
#  [<matplotlib.lines.Line2D at 0x16e121610>],
#  [<matplotlib.lines.Line2D at 0x16e121c50>],
#  [<matplotlib.lines.Line2D at 0x16e13e2d0>],
#  [<matplotlib.lines.Line2D at 0x16e13e910>],
#  [<matplotlib.lines.Line2D at 0x16e13ef50>],
#  [<matplotlib.lines.Line2D at 0x16e12da90>],
#  [<matplotlib.lines.Line2D at 0x16e106c10>],
#  [<matplotlib.lines.Line2D at 0x16e125290>],
#  [<matplotlib.lines.Line2D at 0x16e1258d0>],
#  [<matplotlib.lines.Line2D at 0x16e125f10>],
#  [<matplotlib.lines.Line2D at 0x16e128590>],
#  [<matplotlib.lines.Line2D at 0x16e128bd0>],
#  [<matplotlib.lines.Line2D at 0x16e106710>],
#  [<matplotlib.lines.Line2D at 0x139e0c890>],
#  [<matplotlib.lines.Line2D at 0x139e0ced0>],
#  [<matplotlib.lines.Line2D at 0x139e45550>],
#  [<matplotlib.lines.Line2D at 0x139e45b90>],
#  [<matplotlib.lines.Line2D at 0x139e3f210>],
#  [<matplotlib.lines.Line2D at 0x139e3f850>],
#  [<matplotlib.lines.Line2D at 0x139e3fe90>],
#  [<matplotlib.lines.Line2D at 0x139e26510>],
#  [<matplotlib.lines.Line2D at 0x139e26b50>],
#  [<matplotlib.lines.Line2D at 0x139e171d0>],
#  [<matplotlib.lines.Line2D at 0x139e17810>],
#  [<matplotlib.lines.Line2D at 0x139e17e50>],
#  [<matplotlib.lines.Line2D at 0x139e144d0>],
#  [<matplotlib.lines.Line2D at 0x139e3ffd0>],
#  [<matplotlib.lines.Line2D at 0x139e09190>],
#  [<matplotlib.lines.Line2D at 0x139e097d0>],
#  [<matplotlib.lines.Line2D at 0x139e09e10>],
#  [<matplotlib.lines.Line2D at 0x139e29490>],
#  [<matplotlib.lines.Line2D at 0x139e29ad0>],
#  [<matplotlib.lines.Line2D at 0x139e38150>],
#  [<matplotlib.lines.Line2D at 0x139e14c50>],
#  [<matplotlib.lines.Line2D at 0x139e38dd0>],
#  [<matplotlib.lines.Line2D at 0x139e0e450>],
#  [<matplotlib.lines.Line2D at 0x139e0ea90>],
#  [<matplotlib.lines.Line2D at 0x139e24110>],
#  [<matplotlib.lines.Line2D at 0x139e24750>],
#  [<matplotlib.lines.Line2D at 0x139e24d90>],
#  [<matplotlib.lines.Line2D at 0x139e388d0>],
#  [<matplotlib.lines.Line2D at 0x139e32a50>],
#  [<matplotlib.lines.Line2D at 0x139e190d0>],
#  [<matplotlib.lines.Line2D at 0x139e19710>],
#  [<matplotlib.lines.Line2D at 0x139e19d50>],
#  [<matplotlib.lines.Line2D at 0x139e0d3d0>],
#  [<matplotlib.lines.Line2D at 0x139e0da10>],
#  [<matplotlib.lines.Line2D at 0x139e32550>],
#  [<matplotlib.lines.Line2D at 0x139e1c6d0>],
#  [<matplotlib.lines.Line2D at 0x139e1cd10>],
#  [<matplotlib.lines.Line2D at 0x139e12390>],
#  [<matplotlib.lines.Line2D at 0x139e129d0>],
#  [<matplotlib.lines.Line2D at 0x139e48050>],
#  [<matplotlib.lines.Line2D at 0x139e48690>],
#  [<matplotlib.lines.Line2D at 0x139e1c1d0>],
#  [<matplotlib.lines.Line2D at 0x11ea72350>],
#  [<matplotlib.lines.Line2D at 0x11ea72990>],
#  [<matplotlib.lines.Line2D at 0x11ea51090>],
#  [<matplotlib.lines.Line2D at 0x11ea51650>],
#  [<matplotlib.lines.Line2D at 0x11ea51c90>],
#  [<matplotlib.lines.Line2D at 0x11ea50310>],
#  [<matplotlib.lines.Line2D at 0x139e48e10>],
#  [<matplotlib.lines.Line2D at 0x11ea66050>],
#  [<matplotlib.lines.Line2D at 0x11ea66610>],
#  [<matplotlib.lines.Line2D at 0x11ea66c50>],
#  [<matplotlib.lines.Line2D at 0x11ea522d0>],
#  [<matplotlib.lines.Line2D at 0x11ea52910>],
#  [<matplotlib.lines.Line2D at 0x11ea52f50>],
#  [<matplotlib.lines.Line2D at 0x11ea50a90>],
#  [<matplotlib.lines.Line2D at 0x11ea5cc10>],
#  [<matplotlib.lines.Line2D at 0x11ea4e290>],
#  [<matplotlib.lines.Line2D at 0x11ea4e8d0>],
#  [<matplotlib.lines.Line2D at 0x11ea4ef10>],
#  [<matplotlib.lines.Line2D at 0x11ea49590>],
#  [<matplotlib.lines.Line2D at 0x11ea49bd0>],
#  [<matplotlib.lines.Line2D at 0x11ea5c710>],
#  [<matplotlib.lines.Line2D at 0x11ea5a890>],
#  [<matplotlib.lines.Line2D at 0x11ea5aed0>],
#  [<matplotlib.lines.Line2D at 0x11ea65550>],
#  [<matplotlib.lines.Line2D at 0x11ea65b90>],
#  [<matplotlib.lines.Line2D at 0x11ea7c210>],
#  [<matplotlib.lines.Line2D at 0x11ea7c850>],
#  [<matplotlib.lines.Line2D at 0x11ea7ce90>],
#  [<matplotlib.lines.Line2D at 0x11ea84510>],
#  [<matplotlib.lines.Line2D at 0x11ea84b50>],
#  [<matplotlib.lines.Line2D at 0x11ea4c1d0>],
#  [<matplotlib.lines.Line2D at 0x11ea4c810>],
#  [<matplotlib.lines.Line2D at 0x11ea4ce50>],
#  [<matplotlib.lines.Line2D at 0x11ea684d0>],
#  [<matplotlib.lines.Line2D at 0x11ea7cfd0>],
#  [<matplotlib.lines.Line2D at 0x11ea5f190>],
#  [<matplotlib.lines.Line2D at 0x11ea5f7d0>],
#  [<matplotlib.lines.Line2D at 0x11ea5fe10>],
#  [<matplotlib.lines.Line2D at 0x11ea7b490>],
#  [<matplotlib.lines.Line2D at 0x11ea7bad0>],
#  [<matplotlib.lines.Line2D at 0x11ea54150>],
#  [<matplotlib.lines.Line2D at 0x11ea68c50>],
#  [<matplotlib.lines.Line2D at 0x11ea54dd0>],
#  [<matplotlib.lines.Line2D at 0x11ea80450>],
#  [<matplotlib.lines.Line2D at 0x11ea80a90>],
#  [<matplotlib.lines.Line2D at 0x123f30110>],
#  [<matplotlib.lines.Line2D at 0x123f30750>],
#  [<matplotlib.lines.Line2D at 0x123f30d90>],
#  [<matplotlib.lines.Line2D at 0x11ea548d0>],
#  [<matplotlib.lines.Line2D at 0x123f3ea50>],
#  [<matplotlib.lines.Line2D at 0x123f170d0>],
#  [<matplotlib.lines.Line2D at 0x123f17710>],
#  [<matplotlib.lines.Line2D at 0x123f17d50>],
#  [<matplotlib.lines.Line2D at 0x123f443d0>],
#  [<matplotlib.lines.Line2D at 0x123f44a10>],
#  [<matplotlib.lines.Line2D at 0x123f3e550>],
#  [<matplotlib.lines.Line2D at 0x123f286d0>],
#  [<matplotlib.lines.Line2D at 0x123f28d10>],
#  [<matplotlib.lines.Line2D at 0x123f32390>],
#  [<matplotlib.lines.Line2D at 0x123f329d0>],
#  [<matplotlib.lines.Line2D at 0x123f20050>],
#  [<matplotlib.lines.Line2D at 0x123f20690>],
#  [<matplotlib.lines.Line2D at 0x123f281d0>],
#  [<matplotlib.lines.Line2D at 0x123f3c350>],
#  [<matplotlib.lines.Line2D at 0x123f3c990>],
#  [<matplotlib.lines.Line2D at 0x123f46090>],
#  [<matplotlib.lines.Line2D at 0x123f46650>],
#  [<matplotlib.lines.Line2D at 0x123f46c90>],
#  [<matplotlib.lines.Line2D at 0x123f35310>],
#  [<matplotlib.lines.Line2D at 0x123f20e10>],
#  [<matplotlib.lines.Line2D at 0x123f24050>],
#  [<matplotlib.lines.Line2D at 0x123f24610>],
#  [<matplotlib.lines.Line2D at 0x123f24c50>],
#  [<matplotlib.lines.Line2D at 0x123f492d0>],
#  [<matplotlib.lines.Line2D at 0x123f49910>],
#  [<matplotlib.lines.Line2D at 0x123f49f50>],
#  [<matplotlib.lines.Line2D at 0x123f35a90>],
#  [<matplotlib.lines.Line2D at 0x123f1ac10>],
#  [<matplotlib.lines.Line2D at 0x123f39290>],
#  [<matplotlib.lines.Line2D at 0x123f398d0>],
#  [<matplotlib.lines.Line2D at 0x123f39f10>],
#  [<matplotlib.lines.Line2D at 0x123f3a590>],
#  [<matplotlib.lines.Line2D at 0x123f3abd0>],
#  [<matplotlib.lines.Line2D at 0x123f1a710>],
#  [<matplotlib.lines.Line2D at 0x123f4c890>],
#  [<matplotlib.lines.Line2D at 0x123f4ced0>],
#  [<matplotlib.lines.Line2D at 0x123f38550>],
#  [<matplotlib.lines.Line2D at 0x123f38b90>],
#  [<matplotlib.lines.Line2D at 0x123f36210>],
#  [<matplotlib.lines.Line2D at 0x123f36850>],
#  [<matplotlib.lines.Line2D at 0x123f36e90>],
#  [<matplotlib.lines.Line2D at 0x137cea510>],
#  [<matplotlib.lines.Line2D at 0x137ceab50>],
#  [<matplotlib.lines.Line2D at 0x137ce91d0>],
#  [<matplotlib.lines.Line2D at 0x137ce9810>],
#  [<matplotlib.lines.Line2D at 0x137ce9e50>],
#  [<matplotlib.lines.Line2D at 0x137cd34d0>],
#  [<matplotlib.lines.Line2D at 0x123f36fd0>],
#  [<matplotlib.lines.Line2D at 0x137cbc190>],
#  [<matplotlib.lines.Line2D at 0x137cbc7d0>],
#  [<matplotlib.lines.Line2D at 0x137cbce10>],
#  [<matplotlib.lines.Line2D at 0x137cc5490>],
#  [<matplotlib.lines.Line2D at 0x137cc5ad0>],
#  [<matplotlib.lines.Line2D at 0x137cb0150>],
#  [<matplotlib.lines.Line2D at 0x137cd3c50>],
#  [<matplotlib.lines.Line2D at 0x137cb0dd0>],
#  [<matplotlib.lines.Line2D at 0x137ce2450>],
#  [<matplotlib.lines.Line2D at 0x137ce2a90>],
#  [<matplotlib.lines.Line2D at 0x137cd6110>],
#  [<matplotlib.lines.Line2D at 0x137cd6750>],
#  [<matplotlib.lines.Line2D at 0x137cd6d90>],
#  [<matplotlib.lines.Line2D at 0x137cb08d0>],
#  [<matplotlib.lines.Line2D at 0x137ccfa50>],
#  [<matplotlib.lines.Line2D at 0x137ce30d0>],
#  [<matplotlib.lines.Line2D at 0x137ce3710>],
#  [<matplotlib.lines.Line2D at 0x137ce3d50>],
#  [<matplotlib.lines.Line2D at 0x137cc13d0>],
#  [<matplotlib.lines.Line2D at 0x137cc1a10>],
#  [<matplotlib.lines.Line2D at 0x137ccf550>],
#  [<matplotlib.lines.Line2D at 0x137ccd6d0>],
#  [<matplotlib.lines.Line2D at 0x137ccdd10>],
#  [<matplotlib.lines.Line2D at 0x137cd0390>],
#  [<matplotlib.lines.Line2D at 0x137cd09d0>],
#  [<matplotlib.lines.Line2D at 0x137cae050>],
#  [<matplotlib.lines.Line2D at 0x137cae690>],
#  [<matplotlib.lines.Line2D at 0x137ccd1d0>],
#  [<matplotlib.lines.Line2D at 0x137ce4350>],
#  [<matplotlib.lines.Line2D at 0x137ce4990>],
#  [<matplotlib.lines.Line2D at 0x137cd5090>],
#  [<matplotlib.lines.Line2D at 0x137cd5650>],
#  [<matplotlib.lines.Line2D at 0x137cd5c90>],
#  [<matplotlib.lines.Line2D at 0x137cdc310>],
#  [<matplotlib.lines.Line2D at 0x137caee10>],
#  [<matplotlib.lines.Line2D at 0x11f276050>],
#  [<matplotlib.lines.Line2D at 0x11f276610>],
#  [<matplotlib.lines.Line2D at 0x11f276c50>],
#  [<matplotlib.lines.Line2D at 0x11f2782d0>],
#  [<matplotlib.lines.Line2D at 0x11f278910>],
#  [<matplotlib.lines.Line2D at 0x11f278f50>],
#  [<matplotlib.lines.Line2D at 0x137cdca90>],
#  [<matplotlib.lines.Line2D at 0x11f248c10>],
#  [<matplotlib.lines.Line2D at 0x11f260290>],
#  [<matplotlib.lines.Line2D at 0x11f2608d0>],
#  [<matplotlib.lines.Line2D at 0x11f260f10>],
#  [<matplotlib.lines.Line2D at 0x11f274590>],
#  [<matplotlib.lines.Line2D at 0x11f274bd0>],
#  [<matplotlib.lines.Line2D at 0x11f248710>],
#  [<matplotlib.lines.Line2D at 0x11f269890>],
#  [<matplotlib.lines.Line2D at 0x11f269ed0>],
#  [<matplotlib.lines.Line2D at 0x11f262550>],
#  [<matplotlib.lines.Line2D at 0x11f262b90>],
#  [<matplotlib.lines.Line2D at 0x11f270210>],
#  [<matplotlib.lines.Line2D at 0x11f270850>],
#  [<matplotlib.lines.Line2D at 0x11f270e90>],
#  [<matplotlib.lines.Line2D at 0x11f26d510>],
#  [<matplotlib.lines.Line2D at 0x11f26db50>],
#  [<matplotlib.lines.Line2D at 0x11f2751d0>],
#  [<matplotlib.lines.Line2D at 0x11f275810>],
#  [<matplotlib.lines.Line2D at 0x11f275e50>],
#  [<matplotlib.lines.Line2D at 0x11f2574d0>],
#  [<matplotlib.lines.Line2D at 0x11f270fd0>],
#  [<matplotlib.lines.Line2D at 0x11f258190>],
#  [<matplotlib.lines.Line2D at 0x11f2587d0>],
#  [<matplotlib.lines.Line2D at 0x11f258e10>],
#  [<matplotlib.lines.Line2D at 0x11f27a490>],
#  [<matplotlib.lines.Line2D at 0x11f27aad0>],
#  [<matplotlib.lines.Line2D at 0x11f27b150>],
#  [<matplotlib.lines.Line2D at 0x11f257c50>],
#  [<matplotlib.lines.Line2D at 0x11f27bdd0>],
#  [<matplotlib.lines.Line2D at 0x11f266450>],
#  [<matplotlib.lines.Line2D at 0x11f266a90>],
#  [<matplotlib.lines.Line2D at 0x11f264110>],
#  [<matplotlib.lines.Line2D at 0x11f264750>],
#  [<matplotlib.lines.Line2D at 0x11f264d90>],
#  [<matplotlib.lines.Line2D at 0x11f27b8d0>],
#  [<matplotlib.lines.Line2D at 0x11f255a50>],
#  [<matplotlib.lines.Line2D at 0x11f2630d0>],
#  [<matplotlib.lines.Line2D at 0x11f263710>],
#  [<matplotlib.lines.Line2D at 0x11f263d50>],
#  [<matplotlib.lines.Line2D at 0x16e1a23d0>],
#  [<matplotlib.lines.Line2D at 0x16e1a2a10>],
#  [<matplotlib.lines.Line2D at 0x11f255550>],
#  [<matplotlib.lines.Line2D at 0x16e1a66d0>],
#  [<matplotlib.lines.Line2D at 0x16e1a6d10>],
#  [<matplotlib.lines.Line2D at 0x16e1af390>],
#  [<matplotlib.lines.Line2D at 0x16e1af9d0>],
#  [<matplotlib.lines.Line2D at 0x16e195050>],
#  [<matplotlib.lines.Line2D at 0x16e195690>],
#  [<matplotlib.lines.Line2D at 0x16e1a61d0>],
#  [<matplotlib.lines.Line2D at 0x16e187350>],
#  [<matplotlib.lines.Line2D at 0x16e187990>],
#  [<matplotlib.lines.Line2D at 0x16e1b5090>],
#  [<matplotlib.lines.Line2D at 0x16e1b5650>],
#  [<matplotlib.lines.Line2D at 0x16e1b5c90>],
#  [<matplotlib.lines.Line2D at 0x16e196310>],
#  [<matplotlib.lines.Line2D at 0x16e195e10>],
#  [<matplotlib.lines.Line2D at 0x16e186050>],
#  [<matplotlib.lines.Line2D at 0x16e186610>],
#  [<matplotlib.lines.Line2D at 0x16e186c50>],
#  [<matplotlib.lines.Line2D at 0x16e1992d0>],
#  [<matplotlib.lines.Line2D at 0x16e199910>],
#  [<matplotlib.lines.Line2D at 0x16e199f50>],
#  [<matplotlib.lines.Line2D at 0x16e196a90>],
#  [<matplotlib.lines.Line2D at 0x16e182c10>],
#  [<matplotlib.lines.Line2D at 0x16e18d290>],
#  [<matplotlib.lines.Line2D at 0x16e18d8d0>],
#  [<matplotlib.lines.Line2D at 0x16e18df10>],
#  [<matplotlib.lines.Line2D at 0x16e1aa590>],
#  [<matplotlib.lines.Line2D at 0x16e1aabd0>],
#  [<matplotlib.lines.Line2D at 0x16e182710>],
#  [<matplotlib.lines.Line2D at 0x16e1b7890>],
#  [<matplotlib.lines.Line2D at 0x16e1b7ed0>],
#  [<matplotlib.lines.Line2D at 0x16e1be550>],
#  [<matplotlib.lines.Line2D at 0x16e1beb90>],
#  [<matplotlib.lines.Line2D at 0x16e1ba210>],
#  [<matplotlib.lines.Line2D at 0x16e1ba850>],
#  [<matplotlib.lines.Line2D at 0x16e1bae90>],
#  [<matplotlib.lines.Line2D at 0x16e19a510>],
#  [<matplotlib.lines.Line2D at 0x16e19ab50>],
#  [<matplotlib.lines.Line2D at 0x16e18c1d0>],
#  [<matplotlib.lines.Line2D at 0x16e18c810>],
#  [<matplotlib.lines.Line2D at 0x16e18ce50>],
#  [<matplotlib.lines.Line2D at 0x16e1a04d0>],
#  [<matplotlib.lines.Line2D at 0x16e1bafd0>],
#  [<matplotlib.lines.Line2D at 0x13d6e2190>],
#  [<matplotlib.lines.Line2D at 0x13d6e27d0>],
#  [<matplotlib.lines.Line2D at 0x13d6e2e10>],
#  [<matplotlib.lines.Line2D at 0x13d6de490>],
#  [<matplotlib.lines.Line2D at 0x13d6dead0>],
#  [<matplotlib.lines.Line2D at 0x13d6d2150>],
#  [<matplotlib.lines.Line2D at 0x16e1a0c50>],
#  [<matplotlib.lines.Line2D at 0x13d6d2dd0>],
#  [<matplotlib.lines.Line2D at 0x13d6ff450>],
#  [<matplotlib.lines.Line2D at 0x13d6ffa90>],
#  [<matplotlib.lines.Line2D at 0x13d6c4110>],
#  [<matplotlib.lines.Line2D at 0x13d6c4750>],
#  [<matplotlib.lines.Line2D at 0x13d6c4d90>],
#  [<matplotlib.lines.Line2D at 0x13d6d28d0>],
#  [<matplotlib.lines.Line2D at 0x13d6c8a50>],
#  [<matplotlib.lines.Line2D at 0x13d6ef0d0>],
#  [<matplotlib.lines.Line2D at 0x13d6ef710>],
#  [<matplotlib.lines.Line2D at 0x13d6efd50>],
#  [<matplotlib.lines.Line2D at 0x13d6f73d0>],
#  [<matplotlib.lines.Line2D at 0x13d6f7a10>],
#  [<matplotlib.lines.Line2D at 0x13d6c8550>],
#  [<matplotlib.lines.Line2D at 0x13d6d36d0>],
#  [<matplotlib.lines.Line2D at 0x13d6d3d10>],
#  [<matplotlib.lines.Line2D at 0x13d6db390>],
#  [<matplotlib.lines.Line2D at 0x13d6db9d0>],
#  [<matplotlib.lines.Line2D at 0x13d6d6050>],
#  [<matplotlib.lines.Line2D at 0x13d6d6690>],
#  [<matplotlib.lines.Line2D at 0x13d6d31d0>],
#  [<matplotlib.lines.Line2D at 0x13d6eb350>],
#  [<matplotlib.lines.Line2D at 0x13d6eb990>],
#  [<matplotlib.lines.Line2D at 0x13d6e7090>],
#  [<matplotlib.lines.Line2D at 0x13d6e7650>],
#  [<matplotlib.lines.Line2D at 0x13d6e7c90>],
#  [<matplotlib.lines.Line2D at 0x13d6e4310>],
#  [<matplotlib.lines.Line2D at 0x13d6d6e10>],
#  [<matplotlib.lines.Line2D at 0x13d6d0050>],
#  [<matplotlib.lines.Line2D at 0x13d6d0610>],
#  [<matplotlib.lines.Line2D at 0x13d6d0c50>],
#  [<matplotlib.lines.Line2D at 0x13d6ce2d0>],
#  [<matplotlib.lines.Line2D at 0x13d6ce910>],
#  [<matplotlib.lines.Line2D at 0x13d6cef50>],
#  [<matplotlib.lines.Line2D at 0x13d6e4a90>],
#  [<matplotlib.lines.Line2D at 0x13d6eec10>],
#  [<matplotlib.lines.Line2D at 0x13d6dd290>],
#  [<matplotlib.lines.Line2D at 0x13d6dd8d0>],
#  [<matplotlib.lines.Line2D at 0x13d6ddf10>],
#  [<matplotlib.lines.Line2D at 0x11f3b2590>],
#  [<matplotlib.lines.Line2D at 0x11f3b2bd0>],
#  [<matplotlib.lines.Line2D at 0x13d6ee710>],
#  [<matplotlib.lines.Line2D at 0x11f3d0890>],
#  [<matplotlib.lines.Line2D at 0x11f3d0ed0>],
#  [<matplotlib.lines.Line2D at 0x11f3a7550>],
#  [<matplotlib.lines.Line2D at 0x11f3a7b90>],
#  [<matplotlib.lines.Line2D at 0x11f3ad210>],
#  [<matplotlib.lines.Line2D at 0x11f3ad850>],
#  [<matplotlib.lines.Line2D at 0x11f3ade90>],
#  [<matplotlib.lines.Line2D at 0x11f3a8510>],
#  [<matplotlib.lines.Line2D at 0x11f3a8b50>],
#  [<matplotlib.lines.Line2D at 0x11f3d21d0>],
#  [<matplotlib.lines.Line2D at 0x11f3d2810>],
#  [<matplotlib.lines.Line2D at 0x11f3d2e50>],
#  [<matplotlib.lines.Line2D at 0x11f3bf4d0>],
#  [<matplotlib.lines.Line2D at 0x11f3adfd0>],
#  [<matplotlib.lines.Line2D at 0x11f3a9190>],
#  [<matplotlib.lines.Line2D at 0x11f3a97d0>],
#  [<matplotlib.lines.Line2D at 0x11f3a9e10>],
#  [<matplotlib.lines.Line2D at 0x11f3b6490>],
#  [<matplotlib.lines.Line2D at 0x11f3b6ad0>],
#  [<matplotlib.lines.Line2D at 0x11f3c5150>],
#  [<matplotlib.lines.Line2D at 0x11f3bfc50>],
#  [<matplotlib.lines.Line2D at 0x11f3c5dd0>],
#  [<matplotlib.lines.Line2D at 0x11f3c9450>],
#  [<matplotlib.lines.Line2D at 0x11f3c9a90>],
#  [<matplotlib.lines.Line2D at 0x11f3b9110>],
#  [<matplotlib.lines.Line2D at 0x11f3b9750>],
#  [<matplotlib.lines.Line2D at 0x11f3b9d90>],
#  [<matplotlib.lines.Line2D at 0x11f3c58d0>],
#  [<matplotlib.lines.Line2D at 0x11f3b8a50>],
#  [<matplotlib.lines.Line2D at 0x11f3a50d0>],
#  [<matplotlib.lines.Line2D at 0x11f3a5710>],
#  [<matplotlib.lines.Line2D at 0x11f3a5d50>],
#  [<matplotlib.lines.Line2D at 0x11f3c33d0>],
#  [<matplotlib.lines.Line2D at 0x11f3c3a10>],
#  [<matplotlib.lines.Line2D at 0x11f3b8550>],
#  [<matplotlib.lines.Line2D at 0x11f3b56d0>],
#  [<matplotlib.lines.Line2D at 0x11f3b5d10>],
#  [<matplotlib.lines.Line2D at 0x11f3a3390>],
#  [<matplotlib.lines.Line2D at 0x11f3a39d0>],
#  [<matplotlib.lines.Line2D at 0x11f3d5050>],
#  [<matplotlib.lines.Line2D at 0x11f3d5690>],
#  [<matplotlib.lines.Line2D at 0x11f3b51d0>],
#  [<matplotlib.lines.Line2D at 0x120732350>],
#  [<matplotlib.lines.Line2D at 0x120732990>],
#  [<matplotlib.lines.Line2D at 0x120720090>],
#  [<matplotlib.lines.Line2D at 0x120720650>],
#  [<matplotlib.lines.Line2D at 0x120720c90>],
#  [<matplotlib.lines.Line2D at 0x120705310>],
#  [<matplotlib.lines.Line2D at 0x11f3d5e10>],
#  [<matplotlib.lines.Line2D at 0x12070b050>],
#  [<matplotlib.lines.Line2D at 0x12070b610>],
#  [<matplotlib.lines.Line2D at 0x12070bc50>],
#  [<matplotlib.lines.Line2D at 0x1207282d0>],
#  [<matplotlib.lines.Line2D at 0x120728910>],
#  [<matplotlib.lines.Line2D at 0x120728f50>],
#  [<matplotlib.lines.Line2D at 0x120705a90>],
#  [<matplotlib.lines.Line2D at 0x120713c10>],
#  [<matplotlib.lines.Line2D at 0x12070d290>],
#  [<matplotlib.lines.Line2D at 0x12070d8d0>],
#  [<matplotlib.lines.Line2D at 0x12070df10>],
#  [<matplotlib.lines.Line2D at 0x120736590>],
#  [<matplotlib.lines.Line2D at 0x120736bd0>],
#  [<matplotlib.lines.Line2D at 0x120713710>],
#  [<matplotlib.lines.Line2D at 0x12073a890>],
#  [<matplotlib.lines.Line2D at 0x12073aed0>],
#  [<matplotlib.lines.Line2D at 0x12071c550>],
#  [<matplotlib.lines.Line2D at 0x12071cb90>],
#  [<matplotlib.lines.Line2D at 0x120715210>],
#  [<matplotlib.lines.Line2D at 0x120715850>],
#  [<matplotlib.lines.Line2D at 0x120715e90>],
#  [<matplotlib.lines.Line2D at 0x12070c510>],
#  [<matplotlib.lines.Line2D at 0x12070cb50>],
#  [<matplotlib.lines.Line2D at 0x1207161d0>],
#  [<matplotlib.lines.Line2D at 0x120716810>],
#  [<matplotlib.lines.Line2D at 0x120716e50>],
#  [<matplotlib.lines.Line2D at 0x1207304d0>],
#  [<matplotlib.lines.Line2D at 0x120715fd0>],
#  [<matplotlib.lines.Line2D at 0x12070e190>],
#  [<matplotlib.lines.Line2D at 0x12070e7d0>],
#  [<matplotlib.lines.Line2D at 0x12070ee10>],
#  [<matplotlib.lines.Line2D at 0x12070f490>],
#  [<matplotlib.lines.Line2D at 0x12070fad0>],
#  [<matplotlib.lines.Line2D at 0x120714150>],
#  [<matplotlib.lines.Line2D at 0x120730c50>],
#  [<matplotlib.lines.Line2D at 0x120714dd0>],
#  [<matplotlib.lines.Line2D at 0x120708450>],
#  [<matplotlib.lines.Line2D at 0x120708a90>],
#  [<matplotlib.lines.Line2D at 0x120c6a110>],
#  [<matplotlib.lines.Line2D at 0x120c6a750>],
#  [<matplotlib.lines.Line2D at 0x120c6ad90>],
#  [<matplotlib.lines.Line2D at 0x1207148d0>],
#  [<matplotlib.lines.Line2D at 0x120c7ca50>],
#  [<matplotlib.lines.Line2D at 0x120c800d0>],
#  [<matplotlib.lines.Line2D at 0x120c80710>],
#  [<matplotlib.lines.Line2D at 0x120c80d50>],
#  [<matplotlib.lines.Line2D at 0x120c973d0>],
#  [<matplotlib.lines.Line2D at 0x120c97a10>],
#  [<matplotlib.lines.Line2D at 0x120c7c550>],
#  [<matplotlib.lines.Line2D at 0x120c946d0>],
#  [<matplotlib.lines.Line2D at 0x120c94d10>],
#  [<matplotlib.lines.Line2D at 0x120ca0390>],
#  [<matplotlib.lines.Line2D at 0x120ca09d0>],
#  [<matplotlib.lines.Line2D at 0x120c8d050>],
#  [<matplotlib.lines.Line2D at 0x120c8d690>],
#  [<matplotlib.lines.Line2D at 0x120c941d0>],
#  [<matplotlib.lines.Line2D at 0x120ca2350>],
#  [<matplotlib.lines.Line2D at 0x120ca2990>],
#  [<matplotlib.lines.Line2D at 0x120c70090>],
#  [<matplotlib.lines.Line2D at 0x120c70650>],
#  [<matplotlib.lines.Line2D at 0x120c70c90>],
#  [<matplotlib.lines.Line2D at 0x120c79310>],
#  [<matplotlib.lines.Line2D at 0x120c8de10>],
#  [<matplotlib.lines.Line2D at 0x120c7f050>],
#  [<matplotlib.lines.Line2D at 0x120c7f610>],
#  [<matplotlib.lines.Line2D at 0x120c7fc50>],
#  [<matplotlib.lines.Line2D at 0x120ca82d0>],
#  [<matplotlib.lines.Line2D at 0x120ca8910>],
#  [<matplotlib.lines.Line2D at 0x120ca8f50>],
#  [<matplotlib.lines.Line2D at 0x120c79a90>],
#  [<matplotlib.lines.Line2D at 0x120c6ec10>],
#  [<matplotlib.lines.Line2D at 0x120c76290>],
#  [<matplotlib.lines.Line2D at 0x120c768d0>],
#  [<matplotlib.lines.Line2D at 0x120c76f10>],
#  [<matplotlib.lines.Line2D at 0x120c9b590>],
#  [<matplotlib.lines.Line2D at 0x120c9bbd0>],
#  [<matplotlib.lines.Line2D at 0x120c6e710>],
#  [<matplotlib.lines.Line2D at 0x120c96890>],
#  [<matplotlib.lines.Line2D at 0x120c96ed0>],
#  [<matplotlib.lines.Line2D at 0x120c9d550>],
#  [<matplotlib.lines.Line2D at 0x120c9db90>],
#  [<matplotlib.lines.Line2D at 0x120c8e210>],
#  [<matplotlib.lines.Line2D at 0x120c8e850>],
#  [<matplotlib.lines.Line2D at 0x120c8ee90>],
#  [<matplotlib.lines.Line2D at 0x11eb1a510>],
#  [<matplotlib.lines.Line2D at 0x11eb1ab50>],
#  [<matplotlib.lines.Line2D at 0x11eb251d0>],
#  [<matplotlib.lines.Line2D at 0x11eb25810>],
#  [<matplotlib.lines.Line2D at 0x11eb25e50>],
#  [<matplotlib.lines.Line2D at 0x11eb174d0>],
#  [<matplotlib.lines.Line2D at 0x120c8efd0>],
#  [<matplotlib.lines.Line2D at 0x11eb09190>],
#  [<matplotlib.lines.Line2D at 0x11eb097d0>],
#  [<matplotlib.lines.Line2D at 0x11eb09e10>],
#  [<matplotlib.lines.Line2D at 0x11eb19490>],
#  [<matplotlib.lines.Line2D at 0x11eb19ad0>],
#  [<matplotlib.lines.Line2D at 0x11eb18150>],
#  [<matplotlib.lines.Line2D at 0x11eb17c50>],
#  [<matplotlib.lines.Line2D at 0x11eb18dd0>],
#  [<matplotlib.lines.Line2D at 0x11eb28450>],
#  [<matplotlib.lines.Line2D at 0x11eb28a90>],
#  [<matplotlib.lines.Line2D at 0x11eb2e110>],
#  [<matplotlib.lines.Line2D at 0x11eb2e750>],
#  [<matplotlib.lines.Line2D at 0x11eb2ed90>],
#  [<matplotlib.lines.Line2D at 0x11eb188d0>],
#  [<matplotlib.lines.Line2D at 0x11eb32a50>],
#  [<matplotlib.lines.Line2D at 0x11eb2b0d0>],
#  [<matplotlib.lines.Line2D at 0x11eb2b710>],
#  [<matplotlib.lines.Line2D at 0x11eb2bd50>],
#  [<matplotlib.lines.Line2D at 0x11eb263d0>],
#  [<matplotlib.lines.Line2D at 0x11eb26a10>],
#  [<matplotlib.lines.Line2D at 0x11eb32550>],
#  [<matplotlib.lines.Line2D at 0x11eb1f6d0>],
#  [<matplotlib.lines.Line2D at 0x11eb1fd10>],
#  [<matplotlib.lines.Line2D at 0x11eb29390>],
#  [<matplotlib.lines.Line2D at 0x11eb299d0>],
#  [<matplotlib.lines.Line2D at 0x11eb12050>],
#  [<matplotlib.lines.Line2D at 0x11eb12690>],
#  [<matplotlib.lines.Line2D at 0x11eb1f1d0>],
#  [<matplotlib.lines.Line2D at 0x11eb0e350>],
#  [<matplotlib.lines.Line2D at 0x11eb0e990>],
#  [<matplotlib.lines.Line2D at 0x11eb43090>],
#  [<matplotlib.lines.Line2D at 0x11eb43650>],
#  [<matplotlib.lines.Line2D at 0x11eb43c90>],
#  [<matplotlib.lines.Line2D at 0x11eb20310>],
#  [<matplotlib.lines.Line2D at 0x11eb12e10>],
#  [<matplotlib.lines.Line2D at 0x11eb0a050>],
#  [<matplotlib.lines.Line2D at 0x11eb0a610>],
#  [<matplotlib.lines.Line2D at 0x11eb0ac50>],
#  [<matplotlib.lines.Line2D at 0x11d9b52d0>],
#  [<matplotlib.lines.Line2D at 0x11d9b5910>],
#  [<matplotlib.lines.Line2D at 0x11d9b5f50>],
#  [<matplotlib.lines.Line2D at 0x11eb20a90>],
#  [<matplotlib.lines.Line2D at 0x11d9cec10>],
# ...
#  [<matplotlib.lines.Line2D at 0x189dccd10>],
#  [<matplotlib.lines.Line2D at 0x189dd0390>],
#  [<matplotlib.lines.Line2D at 0x189dd09d0>],
#  [<matplotlib.lines.Line2D at 0x189dd3050>],
#  [<matplotlib.lines.Line2D at 0x189dd3690>],
#  [<matplotlib.lines.Line2D at 0x189dcc1d0>],
#  [<matplotlib.lines.Line2D at 0x189dd6350>],
#  [<matplotlib.lines.Line2D at 0x189dd6990>],
#  [<matplotlib.lines.Line2D at 0x189dda090>],
#  [<matplotlib.lines.Line2D at 0x189dda650>],
#  [<matplotlib.lines.Line2D at 0x189ddac90>],
#  [<matplotlib.lines.Line2D at 0x189ddd310>],
#  [<matplotlib.lines.Line2D at 0x189dd3e10>],
#  [<matplotlib.lines.Line2D at 0x189de0050>],
#  [<matplotlib.lines.Line2D at 0x189de0610>],
#  [<matplotlib.lines.Line2D at 0x189de0c50>],
#  [<matplotlib.lines.Line2D at 0x189de42d0>],
#  [<matplotlib.lines.Line2D at 0x189de4910>],
#  [<matplotlib.lines.Line2D at 0x189de4f50>],
#  [<matplotlib.lines.Line2D at 0x189ddda90>],
#  [<matplotlib.lines.Line2D at 0x189de7c10>],
#  [<matplotlib.lines.Line2D at 0x189dec290>],
#  [<matplotlib.lines.Line2D at 0x189dec8d0>],
#  [<matplotlib.lines.Line2D at 0x189decf10>],
#  [<matplotlib.lines.Line2D at 0x189dee590>],
#  [<matplotlib.lines.Line2D at 0x189deebd0>],
#  [<matplotlib.lines.Line2D at 0x189de7710>],
#  [<matplotlib.lines.Line2D at 0x189df2890>],
#  [<matplotlib.lines.Line2D at 0x189df2ed0>],
#  [<matplotlib.lines.Line2D at 0x189df5550>],
#  [<matplotlib.lines.Line2D at 0x189df5b90>],
#  [<matplotlib.lines.Line2D at 0x189df8210>],
#  [<matplotlib.lines.Line2D at 0x189df8850>],
#  [<matplotlib.lines.Line2D at 0x189df8e90>],
#  [<matplotlib.lines.Line2D at 0x189dfc510>],
#  [<matplotlib.lines.Line2D at 0x189dfcb50>],
#  [<matplotlib.lines.Line2D at 0x189dfe1d0>],
#  [<matplotlib.lines.Line2D at 0x189dfe810>],
#  [<matplotlib.lines.Line2D at 0x189dfee50>],
#  [<matplotlib.lines.Line2D at 0x18a2034d0>],
#  [<matplotlib.lines.Line2D at 0x189df8fd0>],
#  [<matplotlib.lines.Line2D at 0x18a207190>],
#  [<matplotlib.lines.Line2D at 0x18a2077d0>],
#  [<matplotlib.lines.Line2D at 0x18a207e10>],
#  [<matplotlib.lines.Line2D at 0x18a20a490>],
#  [<matplotlib.lines.Line2D at 0x18a20aad0>],
#  [<matplotlib.lines.Line2D at 0x18a20e150>],
#  [<matplotlib.lines.Line2D at 0x18a203c50>],
#  [<matplotlib.lines.Line2D at 0x18a20edd0>],
#  [<matplotlib.lines.Line2D at 0x18a211450>],
#  [<matplotlib.lines.Line2D at 0x18a211a90>],
#  [<matplotlib.lines.Line2D at 0x18a214110>],
#  [<matplotlib.lines.Line2D at 0x18a214750>],
#  [<matplotlib.lines.Line2D at 0x18a214d90>],
#  [<matplotlib.lines.Line2D at 0x18a20e8d0>],
#  [<matplotlib.lines.Line2D at 0x18a218a50>],
#  [<matplotlib.lines.Line2D at 0x18a21c0d0>],
#  [<matplotlib.lines.Line2D at 0x18a21c710>],
#  [<matplotlib.lines.Line2D at 0x18a21cd50>],
#  [<matplotlib.lines.Line2D at 0x18a21f3d0>],
#  [<matplotlib.lines.Line2D at 0x18a21fa10>],
#  [<matplotlib.lines.Line2D at 0x18a218550>],
#  [<matplotlib.lines.Line2D at 0x18a2236d0>],
#  [<matplotlib.lines.Line2D at 0x18a223d10>],
#  [<matplotlib.lines.Line2D at 0x18a224390>],
#  [<matplotlib.lines.Line2D at 0x18a2249d0>],
#  [<matplotlib.lines.Line2D at 0x18a229050>],
#  [<matplotlib.lines.Line2D at 0x18a229690>],
#  [<matplotlib.lines.Line2D at 0x18a2231d0>],
#  [<matplotlib.lines.Line2D at 0x18a22c350>],
#  [<matplotlib.lines.Line2D at 0x18a22c990>],
#  [<matplotlib.lines.Line2D at 0x18a231090>],
#  [<matplotlib.lines.Line2D at 0x18a231650>],
#  [<matplotlib.lines.Line2D at 0x18a231c90>],
#  [<matplotlib.lines.Line2D at 0x18a234310>],
#  [<matplotlib.lines.Line2D at 0x18a229e10>],
#  [<matplotlib.lines.Line2D at 0x18a238050>],
#  [<matplotlib.lines.Line2D at 0x18a238610>],
#  [<matplotlib.lines.Line2D at 0x18a238c50>],
#  [<matplotlib.lines.Line2D at 0x18a23b2d0>],
#  [<matplotlib.lines.Line2D at 0x18a23b910>],
#  [<matplotlib.lines.Line2D at 0x18a23bf50>],
#  [<matplotlib.lines.Line2D at 0x18a234a90>],
#  [<matplotlib.lines.Line2D at 0x18a23ec10>],
#  [<matplotlib.lines.Line2D at 0x18a241290>],
#  [<matplotlib.lines.Line2D at 0x18a2418d0>],
#  [<matplotlib.lines.Line2D at 0x18a241f10>],
#  [<matplotlib.lines.Line2D at 0x18a246590>],
#  [<matplotlib.lines.Line2D at 0x18a246bd0>],
#  [<matplotlib.lines.Line2D at 0x18a23e710>],
#  [<matplotlib.lines.Line2D at 0x18a248890>],
#  [<matplotlib.lines.Line2D at 0x18a248ed0>],
#  [<matplotlib.lines.Line2D at 0x18a24e550>],
#  [<matplotlib.lines.Line2D at 0x18a24eb90>],
#  [<matplotlib.lines.Line2D at 0x18a24f210>],
#  [<matplotlib.lines.Line2D at 0x18a24f850>],
#  [<matplotlib.lines.Line2D at 0x18a24fe90>],
#  [<matplotlib.lines.Line2D at 0x18a254510>],
#  [<matplotlib.lines.Line2D at 0x18a254b50>],
#  [<matplotlib.lines.Line2D at 0x18a2561d0>],
#  [<matplotlib.lines.Line2D at 0x18a256810>],
#  [<matplotlib.lines.Line2D at 0x18a256e50>],
#  [<matplotlib.lines.Line2D at 0x18a25a4d0>],
#  [<matplotlib.lines.Line2D at 0x18a24ffd0>],
#  [<matplotlib.lines.Line2D at 0x18a25e190>],
#  [<matplotlib.lines.Line2D at 0x18a25e7d0>],
#  [<matplotlib.lines.Line2D at 0x18a25ee10>],
#  [<matplotlib.lines.Line2D at 0x18a260490>],
#  [<matplotlib.lines.Line2D at 0x18a260ad0>],
#  [<matplotlib.lines.Line2D at 0x18a265150>],
#  [<matplotlib.lines.Line2D at 0x18a25ac50>],
#  [<matplotlib.lines.Line2D at 0x18a265dd0>],
#  [<matplotlib.lines.Line2D at 0x18a267450>],
#  [<matplotlib.lines.Line2D at 0x18a267a90>],
#  [<matplotlib.lines.Line2D at 0x18a26c110>],
#  [<matplotlib.lines.Line2D at 0x18a26c750>],
#  [<matplotlib.lines.Line2D at 0x18a26cd90>],
#  [<matplotlib.lines.Line2D at 0x18a2658d0>],
#  [<matplotlib.lines.Line2D at 0x18a26ea50>],
#  [<matplotlib.lines.Line2D at 0x18a2710d0>],
#  [<matplotlib.lines.Line2D at 0x18a271710>],
#  [<matplotlib.lines.Line2D at 0x18a271d50>],
#  [<matplotlib.lines.Line2D at 0x18a2763d0>],
#  [<matplotlib.lines.Line2D at 0x18a276a10>],
#  [<matplotlib.lines.Line2D at 0x18a26e550>],
#  [<matplotlib.lines.Line2D at 0x18a2786d0>],
#  [<matplotlib.lines.Line2D at 0x18a278d10>],
#  [<matplotlib.lines.Line2D at 0x18a27c390>],
#  [<matplotlib.lines.Line2D at 0x18a27c9d0>],
#  [<matplotlib.lines.Line2D at 0x18a27f050>],
#  [<matplotlib.lines.Line2D at 0x18a27f690>],
#  [<matplotlib.lines.Line2D at 0x18a2781d0>],
#  [<matplotlib.lines.Line2D at 0x18a281350>],
#  [<matplotlib.lines.Line2D at 0x18a281990>],
#  [<matplotlib.lines.Line2D at 0x18a286090>],
#  [<matplotlib.lines.Line2D at 0x18a286650>],
#  [<matplotlib.lines.Line2D at 0x18a286c90>],
#  [<matplotlib.lines.Line2D at 0x18a288310>],
#  [<matplotlib.lines.Line2D at 0x18a27fe10>],
#  [<matplotlib.lines.Line2D at 0x18a28f050>],
#  [<matplotlib.lines.Line2D at 0x18a28f610>],
#  [<matplotlib.lines.Line2D at 0x18a28fc50>],
#  [<matplotlib.lines.Line2D at 0x18a2922d0>],
#  [<matplotlib.lines.Line2D at 0x18a292910>],
#  [<matplotlib.lines.Line2D at 0x18a292f50>],
#  [<matplotlib.lines.Line2D at 0x18a288a90>],
#  [<matplotlib.lines.Line2D at 0x18a296c10>],
#  [<matplotlib.lines.Line2D at 0x18a299290>],
#  [<matplotlib.lines.Line2D at 0x18a2998d0>],
#  [<matplotlib.lines.Line2D at 0x18a299f10>],
#  [<matplotlib.lines.Line2D at 0x18a29c590>],
#  [<matplotlib.lines.Line2D at 0x18a29cbd0>],
#  [<matplotlib.lines.Line2D at 0x18a296710>],
#  [<matplotlib.lines.Line2D at 0x18a29f890>],
#  [<matplotlib.lines.Line2D at 0x18a29fed0>],
#  [<matplotlib.lines.Line2D at 0x18a2a4550>],
#  [<matplotlib.lines.Line2D at 0x18a2a4b90>],
#  [<matplotlib.lines.Line2D at 0x18a2a6210>],
#  [<matplotlib.lines.Line2D at 0x18a2a6850>],
#  [<matplotlib.lines.Line2D at 0x18a2a6e90>],
#  [<matplotlib.lines.Line2D at 0x18a2aa510>],
#  [<matplotlib.lines.Line2D at 0x18a2aab50>],
#  [<matplotlib.lines.Line2D at 0x18a2ac1d0>],
#  [<matplotlib.lines.Line2D at 0x18a2ac810>],
#  [<matplotlib.lines.Line2D at 0x18a2ace50>],
#  [<matplotlib.lines.Line2D at 0x18a2b14d0>],
#  [<matplotlib.lines.Line2D at 0x18a2a6fd0>],
#  [<matplotlib.lines.Line2D at 0x18a2b3190>],
#  [<matplotlib.lines.Line2D at 0x18a2b37d0>],
#  [<matplotlib.lines.Line2D at 0x18a2b3e10>],
#  [<matplotlib.lines.Line2D at 0x18a2b7490>],
#  [<matplotlib.lines.Line2D at 0x18a2b7ad0>],
#  [<matplotlib.lines.Line2D at 0x18a2bb150>],
#  [<matplotlib.lines.Line2D at 0x18a2b1c50>],
#  [<matplotlib.lines.Line2D at 0x18a2bbdd0>],
#  [<matplotlib.lines.Line2D at 0x18a2bf450>],
#  [<matplotlib.lines.Line2D at 0x18a2bfa90>],
#  [<matplotlib.lines.Line2D at 0x18a2c2110>],
#  [<matplotlib.lines.Line2D at 0x18a2c2750>],
#  [<matplotlib.lines.Line2D at 0x18a2c2d90>],
#  [<matplotlib.lines.Line2D at 0x18a2bb8d0>],
#  [<matplotlib.lines.Line2D at 0x18a2c5a50>],
#  [<matplotlib.lines.Line2D at 0x18a2c80d0>],
#  [<matplotlib.lines.Line2D at 0x18a2c8710>],
#  [<matplotlib.lines.Line2D at 0x18a2c8d50>],
#  [<matplotlib.lines.Line2D at 0x18a2cb3d0>],
#  [<matplotlib.lines.Line2D at 0x18a2cba10>],
#  [<matplotlib.lines.Line2D at 0x18a2c5550>],
#  [<matplotlib.lines.Line2D at 0x18a2ce6d0>],
#  [<matplotlib.lines.Line2D at 0x18a2ced10>],
#  [<matplotlib.lines.Line2D at 0x18a2d4390>],
#  [<matplotlib.lines.Line2D at 0x18a2d49d0>],
#  [<matplotlib.lines.Line2D at 0x18a2d7050>],
#  [<matplotlib.lines.Line2D at 0x18a2d7690>],
#  [<matplotlib.lines.Line2D at 0x18a2ce1d0>],
#  [<matplotlib.lines.Line2D at 0x18a2db350>],
#  [<matplotlib.lines.Line2D at 0x18a2db990>],
#  [<matplotlib.lines.Line2D at 0x18a2dd090>],
#  [<matplotlib.lines.Line2D at 0x18a2dd650>],
#  [<matplotlib.lines.Line2D at 0x18a2ddc90>],
#  [<matplotlib.lines.Line2D at 0x18a2e1310>],
#  [<matplotlib.lines.Line2D at 0x18a2d7e10>],
#  [<matplotlib.lines.Line2D at 0x18a2e4050>],
#  [<matplotlib.lines.Line2D at 0x18a2e4610>],
#  [<matplotlib.lines.Line2D at 0x18a2e4c50>],
#  [<matplotlib.lines.Line2D at 0x18a2e92d0>],
#  [<matplotlib.lines.Line2D at 0x18a2e9910>],
#  [<matplotlib.lines.Line2D at 0x18a2e9f50>],
#  [<matplotlib.lines.Line2D at 0x18a2e1a90>],
#  [<matplotlib.lines.Line2D at 0x18a2ecc10>],
#  [<matplotlib.lines.Line2D at 0x18a2ef290>],
#  [<matplotlib.lines.Line2D at 0x18a2ef8d0>],
#  [<matplotlib.lines.Line2D at 0x18a2eff10>],
#  [<matplotlib.lines.Line2D at 0x18a2f1590>],
#  [<matplotlib.lines.Line2D at 0x18a2f1bd0>],
#  [<matplotlib.lines.Line2D at 0x18a2ec710>],
#  [<matplotlib.lines.Line2D at 0x18a2f6890>],
#  [<matplotlib.lines.Line2D at 0x18a2f6ed0>],
#  [<matplotlib.lines.Line2D at 0x18a2f9550>],
#  [<matplotlib.lines.Line2D at 0x18a2f9b90>],
#  [<matplotlib.lines.Line2D at 0x18a2fd210>],
#  [<matplotlib.lines.Line2D at 0x18a2fd850>],
#  [<matplotlib.lines.Line2D at 0x18a2fde90>],
#  [<matplotlib.lines.Line2D at 0x18a701510>],
#  [<matplotlib.lines.Line2D at 0x18a701b50>],
#  [<matplotlib.lines.Line2D at 0x18a7041d0>],
#  [<matplotlib.lines.Line2D at 0x18a704810>],
#  [<matplotlib.lines.Line2D at 0x18a704e50>],
#  [<matplotlib.lines.Line2D at 0x18a7074d0>],
#  [<matplotlib.lines.Line2D at 0x18a2fdfd0>],
#  [<matplotlib.lines.Line2D at 0x18a70b190>],
#  [<matplotlib.lines.Line2D at 0x18a70b7d0>],
#  [<matplotlib.lines.Line2D at 0x18a70be10>],
#  [<matplotlib.lines.Line2D at 0x18a70e490>],
#  [<matplotlib.lines.Line2D at 0x18a70ead0>],
#  [<matplotlib.lines.Line2D at 0x18a712150>],
#  [<matplotlib.lines.Line2D at 0x18a707c50>],
#  [<matplotlib.lines.Line2D at 0x18a712dd0>],
#  [<matplotlib.lines.Line2D at 0x18a713450>],
#  [<matplotlib.lines.Line2D at 0x18a713a90>],
#  [<matplotlib.lines.Line2D at 0x18a71b110>],
#  [<matplotlib.lines.Line2D at 0x18a71b750>],
#  [<matplotlib.lines.Line2D at 0x18a71bd90>],
#  [<matplotlib.lines.Line2D at 0x18a7128d0>],
#  [<matplotlib.lines.Line2D at 0x18a71ca50>],
#  [<matplotlib.lines.Line2D at 0x18a7200d0>],
#  [<matplotlib.lines.Line2D at 0x18a720710>],
#  [<matplotlib.lines.Line2D at 0x18a720d50>],
#  [<matplotlib.lines.Line2D at 0x18a7233d0>],
#  [<matplotlib.lines.Line2D at 0x18a723a10>],
#  [<matplotlib.lines.Line2D at 0x18a71c550>],
#  [<matplotlib.lines.Line2D at 0x18a7266d0>],
#  [<matplotlib.lines.Line2D at 0x18a726d10>],
#  [<matplotlib.lines.Line2D at 0x18a72a390>],
#  [<matplotlib.lines.Line2D at 0x18a72a9d0>],
#  [<matplotlib.lines.Line2D at 0x18a72e050>],
#  [<matplotlib.lines.Line2D at 0x18a72e690>],
#  [<matplotlib.lines.Line2D at 0x18a7261d0>],
#  [<matplotlib.lines.Line2D at 0x18a731350>],
#  [<matplotlib.lines.Line2D at 0x18a731990>],
#  [<matplotlib.lines.Line2D at 0x18a735090>],
#  [<matplotlib.lines.Line2D at 0x18a735650>],
#  [<matplotlib.lines.Line2D at 0x18a735c90>],
#  [<matplotlib.lines.Line2D at 0x18a737310>],
#  [<matplotlib.lines.Line2D at 0x18a72ee10>],
#  [<matplotlib.lines.Line2D at 0x18a73c050>],
#  [<matplotlib.lines.Line2D at 0x18a73c610>],
#  [<matplotlib.lines.Line2D at 0x18a73cc50>],
#  [<matplotlib.lines.Line2D at 0x18a73e2d0>],
#  [<matplotlib.lines.Line2D at 0x18a73e910>],
#  [<matplotlib.lines.Line2D at 0x18a73ef50>],
#  [<matplotlib.lines.Line2D at 0x18a737a90>],
#  [<matplotlib.lines.Line2D at 0x18a743c10>],
#  [<matplotlib.lines.Line2D at 0x18a745290>],
#  [<matplotlib.lines.Line2D at 0x18a7458d0>],
#  [<matplotlib.lines.Line2D at 0x18a745f10>],
#  [<matplotlib.lines.Line2D at 0x18a749590>],
#  [<matplotlib.lines.Line2D at 0x18a749bd0>],
#  [<matplotlib.lines.Line2D at 0x18a743710>],
#  [<matplotlib.lines.Line2D at 0x18a74c890>],
#  [<matplotlib.lines.Line2D at 0x18a74ced0>],
#  [<matplotlib.lines.Line2D at 0x18a74f550>],
#  [<matplotlib.lines.Line2D at 0x18a74fb90>],
#  [<matplotlib.lines.Line2D at 0x18a753210>],
#  [<matplotlib.lines.Line2D at 0x18a753850>],
#  [<matplotlib.lines.Line2D at 0x18a753e90>],
#  [<matplotlib.lines.Line2D at 0x18a756510>],
#  [<matplotlib.lines.Line2D at 0x18a756b50>],
#  [<matplotlib.lines.Line2D at 0x18a75b1d0>],
#  [<matplotlib.lines.Line2D at 0x18a75b810>],
#  [<matplotlib.lines.Line2D at 0x18a75be50>],
#  [<matplotlib.lines.Line2D at 0x18a75f4d0>],
#  [<matplotlib.lines.Line2D at 0x18a753fd0>],
#  [<matplotlib.lines.Line2D at 0x18a762190>],
#  [<matplotlib.lines.Line2D at 0x18a7627d0>],
#  [<matplotlib.lines.Line2D at 0x18a762e10>],
#  [<matplotlib.lines.Line2D at 0x18a766490>],
#  [<matplotlib.lines.Line2D at 0x18a766ad0>],
#  [<matplotlib.lines.Line2D at 0x18a769150>],
#  [<matplotlib.lines.Line2D at 0x18a75fc50>],
#  [<matplotlib.lines.Line2D at 0x18a769dd0>],
#  [<matplotlib.lines.Line2D at 0x18a76d450>],
#  [<matplotlib.lines.Line2D at 0x18a76da90>],
#  [<matplotlib.lines.Line2D at 0x18a76f110>],
#  [<matplotlib.lines.Line2D at 0x18a76f750>],
#  [<matplotlib.lines.Line2D at 0x18a76fd90>],
#  [<matplotlib.lines.Line2D at 0x18a7698d0>],
#  [<matplotlib.lines.Line2D at 0x18a772a50>],
#  [<matplotlib.lines.Line2D at 0x18a7770d0>],
#  [<matplotlib.lines.Line2D at 0x18a777710>],
#  [<matplotlib.lines.Line2D at 0x18a777d50>],
#  [<matplotlib.lines.Line2D at 0x18a7793d0>],
#  [<matplotlib.lines.Line2D at 0x18a779a10>],
#  [<matplotlib.lines.Line2D at 0x18a772550>],
#  [<matplotlib.lines.Line2D at 0x18a77e6d0>],
#  [<matplotlib.lines.Line2D at 0x18a77ed10>],
#  [<matplotlib.lines.Line2D at 0x18a780390>],
#  [<matplotlib.lines.Line2D at 0x18a7809d0>],
#  [<matplotlib.lines.Line2D at 0x18a784050>],
#  [<matplotlib.lines.Line2D at 0x18a784690>],
#  [<matplotlib.lines.Line2D at 0x18a77e1d0>],
#  [<matplotlib.lines.Line2D at 0x18a787350>],
#  [<matplotlib.lines.Line2D at 0x18a787990>],
#  [<matplotlib.lines.Line2D at 0x18a78b090>],
#  [<matplotlib.lines.Line2D at 0x18a78b650>],
#  [<matplotlib.lines.Line2D at 0x18a78bc90>],
#  [<matplotlib.lines.Line2D at 0x18a78f310>],
#  [<matplotlib.lines.Line2D at 0x18a784e10>],
#  [<matplotlib.lines.Line2D at 0x18a792050>],
#  [<matplotlib.lines.Line2D at 0x18a792610>],
#  [<matplotlib.lines.Line2D at 0x18a792c50>],
#  [<matplotlib.lines.Line2D at 0x18a7952d0>],
#  [<matplotlib.lines.Line2D at 0x18a795910>],
#  [<matplotlib.lines.Line2D at 0x18a795f50>],
#  [<matplotlib.lines.Line2D at 0x18a78fa90>],
#  [<matplotlib.lines.Line2D at 0x18a798c10>],
#  [<matplotlib.lines.Line2D at 0x18a79a290>],
#  [<matplotlib.lines.Line2D at 0x18a79a8d0>],
#  [<matplotlib.lines.Line2D at 0x18a79af10>],
#  [<matplotlib.lines.Line2D at 0x18a7a0590>],
#  [<matplotlib.lines.Line2D at 0x18a7a0bd0>],
#  [<matplotlib.lines.Line2D at 0x18a798710>],
#  [<matplotlib.lines.Line2D at 0x18a7a3890>],
#  [<matplotlib.lines.Line2D at 0x18a7a3ed0>],
#  [<matplotlib.lines.Line2D at 0x18a7a7550>],
#  [<matplotlib.lines.Line2D at 0x18a7a7b90>],
#  [<matplotlib.lines.Line2D at 0x18a7aa210>],
#  [<matplotlib.lines.Line2D at 0x18a7aa850>],
#  [<matplotlib.lines.Line2D at 0x18a7aae90>],
#  [<matplotlib.lines.Line2D at 0x18a7ae510>],
#  [<matplotlib.lines.Line2D at 0x18a7aeb50>],
#  [<matplotlib.lines.Line2D at 0x18a7b11d0>],
#  [<matplotlib.lines.Line2D at 0x18a7b1810>],
#  [<matplotlib.lines.Line2D at 0x18a7b1e50>],
#  [<matplotlib.lines.Line2D at 0x18a7b44d0>]]

# %%
argwhere(mask_0000)
# Out:
# array([[    1],
#        [    5],
#        [    7],
#        ...,
#        [54244],
#        [54251],
#        [54259]])

# %%
pca_01 = srtr.PCATransform(sp,mask_01,defaults.pca_trans)
pca_01.transform()
km_01 = srtr.KMeansCluster(sp,mask_01,pca_01.trnsmtrx,defaults.km_cluster)
km_01.select()
sview.plot_clusters(sp,km_01)
display(gcf())

# %%
mask_010 = km_01.mask_from_labels('0')
mask_011 = km_01.mask_from_labels('1')
sview.plot_select_trains(sp,[mask_00,mask_010,mask_011])

# %%
md_params = {'trans_dims':1}
mdt_011 = srtr.MedTrans(sp,mask_011,md_params)
mdt_011.transform()
th_011 = srtr.ThreshSelector(sp,mask_011,mdt_011.trnsmtrx,{})
thresh = percentile(mdt_011.trnsmtrx,98)
th_011.select(thresh)
sview.plot_clusters(sp,th_011)
display(gcf())

# %%
mask_0110 = th_011.mask_from_labels('0')
mask_0111 = th_011.mask_from_labels('1')
sview.plot_select_trains(sp,[mask_00,mask_010,mask_011,mask_0110,mask_0111])

# %%
comb_mask = mask_00 | mask_010 | mask_0110

# %%
sview.plot_select_trains(sp,[comb_mask,~comb_mask])

# %%
sp.annotations['spk_mask']  = comb_mask

# %%
fly.processed_signals['spike_pool'].annotations
# Out:
# {'spk_mask': array([ True,  True,  True, ...,  True,  True,  True], dtype=bool)}

# %%
fly.save_data('flydata.cpkl')

# %%
p2p_01 = srtr.P2PTransform(sp,null_mask,{'trans_dims':1})
p2p_01.transform()
km_settings = {'kmeans_nc':2,'init':'k-means++'}
km_01 = srtr.KMeansCluster(sp,mask_01,p2p_01.trnsmtrx,km_settings)
km_01.select()
#hist(p2p_0.trnsmtrx[:,1],bins = 100)
sview.plot_clusters(sp,km_01)
display(gcf())
# Out:
# (66260,)
# (66260,)

# %%
f = figure()
ax = Axes3D(f)
colors = cm.jet(array(km_01.labels == '0',dtype = float))
ax.scatter(pca_01.trnsmtrx[:5000,0],pca_01.trnsmtrx[:5000,1],pca_01.trnsmtrx[:5000,2],c= colors[:5000,:])
